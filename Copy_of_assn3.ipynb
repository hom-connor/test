# %% [markdown]
# <a href="https://colab.research.google.com/github/hom-connor/test/blob/main/Copy_of_assn3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Introductory Machine Learning: Assignment 3
#
# **Deadline:**
#
# Assignment 3 is due Thursday, March 26 at 11:59pm. Late work will not be accepted as per the course policies (see the Syllabus and Course policies on [Canvas](https://canvas.yale.edu)).
#
# Directly sharing answers is not okay, but discussing problems with the course staff or with other students is encouraged.
#
# You should start early so that you have time to get help if you're stuck. The drop-in office hours schedule can be found on [Canvas](https://canvas.yale.edu).  You can also post questions or start discussions on [Ed Discussion](https://edstem.org/us/courses/9209/discussion/). The problems are broken up into steps that should help you to make steady progress.
#
# **Submission:**
#
# Submit your assignment as a .pdf on Gradescope, and as a .ipynb on Canvas. You can access Gradescope through Canvas on the left-side of the class home page. The problems in each homework assignment are numbered.
#
# Note:
# 1. Please **assign each sub-question on Gradescope** correctly. This ensures all questions are visible and helps TAs grade efficiently.
# 2. Double-check that **your PDF is complete** before submission.
# 3. For both text and mathematical answers, please use **markdown blocks** instead of code block notes. This prevents answers from being cut off and improves readability. Also, ensure you run every cell before knitting, as un-run markdown cells may have formatting issues.
#
# To produce the .pdf, please convert to html and then print to pdf. (You may want to use your pdf print menu to scale the pages to be sure that cells are not truncated.) To convert to html, you can use this [converter notebook](https://colab.research.google.com/github/YData123/sds265-sp26/blob/main/assignments/Convert_ipynb_to_HTML_in_Colab.ipynb).
#
#
# **Topics**
# 1. Random forests
# 2. Principal components analysis
# 3. Bayes’ theorem

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %% [markdown]
# ## Problem 1: Identifying factors impacting global life expectancy through the trees (25 points)
#
# The Global Health Observatory (GHO) under the World Health Organization (WHO) tracks health status and related factors for all countries. Their life expectancy dataset includes variables like immunization, mortality, and economic and social factors, helping to identify key areas for improving a country’s life expectancy.
#
# <p align="center">
#   <img src="https://raw.githubusercontent.com/YData123/sds265-fa24/main/assignments/assn3/life_expectancy.png" width="600" height="300">
# </p>

# %% [markdown]
# In this problem, we’ll leverage the power of regression decision trees and regression forests random forests to explore the factors influencing life expectancy and predict it. Are you ready to dive into the data and see how we might live longer?

# %%
# Load the dataset. Don't change it.
life_expectancy = pd.read_csv("https://raw.githubusercontent.com/YData123/sds265-sp26/main/assignments/assn3/life_expectancy_data.csv")
life_expectancy = life_expectancy.drop(columns = [' thinness  1-19 years', ' thinness 5-9 years', 'under-five deaths ', 'Total expenditure'])
life_expectancy.rename(columns={'Life expectancy ': 'Life expectancy', 'Measles ': 'Measles', ' BMI ': 'BMI',
                                'Diphtheria ': 'Diphtheria', ' HIV/AIDS': 'HIV/AIDS','infant deaths': 'Infant deaths', 'percentage expenditure': 'Percentage expenditure'}, inplace=True)
life_expectancy = life_expectancy.dropna()
life_expectancy.head()
# Out:
#        Country  Year      Status  Life expectancy  Adult Mortality  \
# 0  Afghanistan  2015  Developing             65.0            263.0
# 1  Afghanistan  2014  Developing             59.9            271.0
# 2  Afghanistan  2013  Developing             59.9            268.0
# 3  Afghanistan  2012  Developing             59.5            272.0
# 4  Afghanistan  2011  Developing             59.2            275.0
#
#    Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles   BMI  \
# 0             62     0.01               71.279624         65.0     1154  19.1
# 1             64     0.01               73.523582         62.0      492  18.6
# 2             66     0.01               73.219243         64.0      430  18.1
# 3             69     0.01               78.184215         67.0     2787  17.6
# 4             71     0.01                7.097109         68.0     3013  17.2
#
#    Polio  Diphtheria  HIV/AIDS         GDP  Population  \
# 0    6.0        65.0       0.1  584.259210  33736494.0
# 1   58.0        62.0       0.1  612.696514    327582.0
# 2   62.0        64.0       0.1  631.744976  31731688.0
# 3   67.0        67.0       0.1  669.959000   3696958.0
# 4   68.0        68.0       0.1   63.537231   2978599.0
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
# 3                            0.463        9.8
# 4                            0.454        9.5

# %% [markdown]
# You can find the desciption of each column as follows:
# - `Country` : Country
# - `Year` : Year
# - `Status` : Country Developed or Developing status
# - `Life expectancy` : Life expectancy in age
# - `Adult Mortality` : Adult Mortality Rates of both sexes (probability of dying between 15 and 60 years per 1000 population)
# - `Infant deaths` : Number of Infant Deaths per 1000 population
# - `Alcohol` : Alcohol, recorded per capita (15+) consumption (in litres of pure alcohol) -percentage expenditure: Expenditure on health as a percentage of Gross Domestic Product per capita(%)
# - `Percentage expenditure`: Expenditure on health as a percentage of Gross Domestic Product per capita(%)
# - `Hepatitis B` : Hepatitis B (HepB) immunization coverage among 1-year-olds (%)
# - `Measles` : Measles - number of reported cases per 1000 population
# - `BMI` : Average Body Mass Index of entire population
# - `Polio` : Polio (Pol3) immunization coverage among 1-year-olds (%)
# - `Diphtheria` : Diphtheria tetanus toxoid and pertussis (DTP3) immunization coverage among 1-year-olds (%)
# - `HIV/AIDS` : Deaths per 1000 live births HIV/AIDS (0-4 years)
# - `GDP` : Gross Domestic Product per capita (in USD)
# - `Population` : Population of the country
# - `Income composition of resources` : Human Development Index in terms of income composition of resources (index ranging from 0 to 1)
# - `Schooling` : Number of years of Schooling(years)

# %% [markdown]
# We will focus on the numerical data. We first select the predictor variables X and the response variable 'Life expectancy'. Then we use `train_test_split` to randomly split the data into training and test sets.

# %%
# Just run the cell.
life_expectancy = life_expectancy.drop(columns = ['Country', 'Status'])

from sklearn.model_selection import train_test_split
y = life_expectancy['Life expectancy']
X = life_expectancy.drop('Life expectancy', axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# %% [markdown]
# ### 1.1 Building a simple regression tree
#
# Let's start with two of the predictor variables: `HIV/AIDS` (Deaths per 1 000 live births HIV/AIDS (0-4 years)) and `Income composition of resources` (Human Development Index in terms of income composition of resources). You will *manually* build a regression tree using these two variables step by step.

# %% [markdown]
# #### Problem 1.1.a
#
# First, make two scatter plots: 'Life Expectancy' vs. 'HIV/AIDS' and 'Life Expectancy' vs. 'Income Composition of Resources'.

# %%
hiv = X_train['HIV/AIDS'].values
income = X_train['Income composition of resources'].values
expectancy = y_train.values

### your code starts here
fig = plt.figure(figsize=(10, 5))
plt.scatter(hiv, expectancy, label='Life Expectancy')
plt.xlabel('HIV/AIDS')
plt.ylabel('Life Expectancy')
plt.title('Life Expectancy vs. HIV/AIDS')
plt.show()

fig = plt.figure(figsize=(10, 5))
plt.scatter(income, expectancy, label='Life Expectancy')
plt.xlabel('Income Composition of Resources')
plt.ylabel('Life Expectancy')
plt.title('Life Expectancy vs. Income Composition of Resources')
plt.show()

# %% [markdown]
# We can plot Life Expectancy indicated by color using a colormap, and see how life expectancy depends on these two.

# %%
# Just run it, no need to change.
plt.figure(figsize=(7, 4))
scatter = plt.scatter(hiv, income, c=expectancy, cmap='jet')
plt.title('Life Expectancy vs. HIV/AIDS and Income Composition of Resources')
plt.xlabel('HIV/AIDS')
plt.ylabel('Income Composition of Resources')
cbar = plt.colorbar(scatter)
cbar.set_label('Life Expectancy')
plt.xscale("log")
plt.show()

# %% [markdown]
# What can you observe from these plots? How do you think this could help in building decision trees? Briefly explain your thoughts in 2-3 sentences.

# %% [markdown]
# We see a very high concentration of red and orange in the top left corner, indicating countries with higher life expectancies are likely to have low rates of HIV/AIDS and higher income compositions.
#
# Moving right on the plot, we see that the dots get bluer and bluer, indicating that life expectancy drops heavily as the rate of HIV/AIDS increases and as income composition decreases.
#
# So we can use this to build decision trees by separating countries into lower or higher rates of HIV/AIDS, levels of income composition and other factors that commonly divide countries into differing life expectancies.

# %% [markdown]
# #### Problem 1.1.b

# %% [markdown]
# Next, we can define a function to find the best split for a simple regression tree based on a single feature to minimize the mean squared error (MSE). This function is provided for you, and it can be helpful for a fundamental understanding of building a decision tree from scratch.
#
# - feature (np.array): The feature data used for finding the split (e.g. `hiv`).
# - target (np.array): The target data used for calculating MSE (e.g. `expectancy`).
#
# Use the `find_best_split` function provided to find the best split and the MSE using 'HIV/AIDS' and 'Income Composition of Resources'.

# %%
# Don't change it
def find_best_split(feature, target):
    sorted_ind = np.argsort(feature)
    feature_sorted = feature[sorted_ind]
    target_sorted = target[sorted_ind]

    best_mse = float('inf')
    best_split = None

    for i in range(1, len(feature_sorted)):
        if feature_sorted[i] == feature_sorted[i - 1]:
            continue
        split_val = (feature_sorted[i] + feature_sorted[i - 1]) / 2
        left_target = target_sorted[:i]
        right_target = target_sorted[i:]
        left_mse = np.mean((left_target - np.mean(left_target))**2)
        right_mse = np.mean((right_target - np.mean(right_target))**2)
        # Compute weighted average of MSEs
        total_mse = (left_mse * len(left_target) + right_mse * len(right_target)) / len(feature)
        if total_mse < best_mse:
            best_mse = total_mse
            best_split = split_val
    return best_split, best_mse

# %%
### your code starts here
best_hiv_split, best_hiv_mse = find_best_split(hiv, expectancy)
best_income_split, best_income_mse = find_best_split(income, expectancy)
print(best_hiv_split, best_hiv_mse)
print(best_income_split, best_income_mse)
# Out:
# 0.6499999999999999 38.1941571086522
# 0.6315 37.04390243663883

# %% [markdown]
# **Which one do you think is the best feature for the first split? Why?**

# %% [markdown]
# I think that the best feature for the first split is income composition. This is because it has a slightly lower mean squared error of 37.04 compared to the mean squared error of HIV/AIDS at 38.19

# %%
# Run this to see if your answer is correct!
if best_hiv_mse < best_income_mse:
    chosen_name = 'HIV/AIDS'
    another_name = 'Income Composition of Resources'
    chosen_split = best_hiv_split
    chosen_feature = hiv
    another_feature = income
else:
    chosen_name = 'Income Composition of Resources'
    another_name = 'HIV/AIDS'
    chosen_split = best_income_split
    chosen_feature = income
    another_feature = hiv

print(f"Best first split is on {chosen_name} at {chosen_split:.2f}")
# Out:
# Best first split is on Income Composition of Resources at 0.63

# %% [markdown]
# We’ve successfully made the first split for our regression tree! The data is now divided into two parts: the left subtree and the right subtree. To grow the tree further, we need to determine which feature to use for splitting the left and right subtrees.

# %%
# Just run it. Don't change!
mask = chosen_feature <= chosen_split
left_feature_chosen, left_feature, left_target = chosen_feature[mask], another_feature[mask], expectancy[mask]
right_feature_chosen, right_feature, right_target = chosen_feature[~mask], another_feature[~mask], expectancy[~mask]

left_split, left_mse = find_best_split(left_feature, left_target)
left_split_chosen, left_mse_chosen = find_best_split(left_feature_chosen, left_target)
right_split, right_mse = find_best_split(right_feature, right_target)
right_split_chosen, right_mse_chosen = find_best_split(right_feature_chosen, right_target)

print(f"Left Split for {another_name}: {left_split:.2f}, Best MSE: {left_mse:.2f}")
print(f"Left Split for {chosen_name}: {left_split_chosen:.2f}, Best MSE: {left_mse_chosen:.2f}")
print(f"Right Split for {another_name}: {right_split:.2f}, Best MSE: {right_mse:.2f}")
print(f"Right Split for {chosen_name}: {right_split_chosen:.2f}, Best MSE: {right_mse_chosen:.2f}")
# Out:
# Left Split for HIV/AIDS: 1.35, Best MSE: 27.23
# Left Split for Income Composition of Resources: 0.51, Best MSE: 40.22
# Right Split for HIV/AIDS: 0.25, Best MSE: 20.18
# Right Split for Income Composition of Resources: 0.80, Best MSE: 13.32

# %% [markdown]
# **Based on the above results, find the correct feature (`left_name` and `right_name`) and split points for left subtree and right subtree (`left_split` and `right_split`).**

# %%
### your code starts here, not necessarily one line for each
left_name = 'HIV/AIDS'
right_name = 'Income Composition of Resources'
left_split = left_split_chosen
right_split = right_split_chosen

# %%
# Run this cell to see the tree you've grown!
plt.figure(figsize=(10, 5))
plt.scatter(chosen_feature, another_feature, c=expectancy, cmap='jet')
plt.axvline(x=chosen_split, color='red', linestyle='--', label=f'Split at {chosen_split:.2f}')
if left_name == chosen_name:
    plt.axvline(x=left_split, color='blue', linestyle='--', label=f'Split at {left_split:.2f}')
else:
    plt.hlines(y=left_split, xmin=min(chosen_feature), xmax=chosen_split, colors='blue', linestyle='--', label=f'Split at {left_split:.2f}')
if right_name == chosen_name:
    plt.axvline(x=right_split, color='green', linestyle='--',  label=f'Split at {right_split:.2f}')
else:
    plt.hlines(y=right_split, xmin=chosen_split, xmax=max(chosen_feature), colors='green', linestyle='--',  label=f'Split at {right_split:.2f}')
plt.colorbar(label='Life Expectancy')
plt.xlabel(chosen_name)
plt.ylabel(another_name)
if chosen_name == 'HIV/AIDS':
    plt.xscale("log")
else:
    plt.yscale("log")
plt.legend(loc='lower left')
plt.title('Decision Tree: Splits on HIV/AIDS and Income Composition of Resources')
plt.show()

# %% [markdown]
# ### 1.2 Fitting a full regression tree and plot it
#
# Now build a tree that uses all the predictor variables, has a more flexible structure, and is validated with a test set. Remember that we have split the full dataset into a training set and a test set. Fit a regression tree to the training set using the function `DecisionTreeRegressor` from `sklearn.tree`. For now, use your best judgment to choose parameters for tree complexity. Plot your decision tree use `plot_tree` function.

# %%
from sklearn import tree

### Your code starts here
# tree parameters go inside the first set of parentheses and the training data
# goes in the second set of parentheses
my_tree = tree.DecisionTreeRegressor()
my_tree = my_tree.fit(X_train, y_train)


plt.figure(figsize=(10, 10))
tree.plot_tree(my_tree)
# Out:
# [Text(0.5648044436237816, 0.9772727272727273, 'x[13] <= 0.632\nsquared_error = 75.94\nsamples = 989\nvalue = 68.982'),
#  Text(0.2770705090940944, 0.9318181818181818, 'x[10] <= 1.35\nsquared_error = 53.539\nsamples = 426\nvalue = 61.812'),
#  Text(0.42093747635893797, 0.9545454545454546, 'True  '),
#  Text(0.1676723657386762, 0.8863636363636364, 'x[1] <= 227.5\nsquared_error = 21.676\nsamples = 257\nvalue = 65.971'),
#  Text(0.11916488819519654, 0.8409090909090909, 'x[4] <= 190.834\nsquared_error = 13.582\nsamples = 182\nvalue = 67.856'),
#  Text(0.06668869847741607, 0.7954545454545454, 'x[14] <= 7.85\nsquared_error = 11.241\nsamples = 143\nvalue = 66.917'),
#  Text(0.011483085939988534, 0.75, 'x[1] <= 28.0\nsquared_error = 8.37\nsamples = 23\nvalue = 63.687'),
#  Text(0.007581066445817672, 0.7045454545454546, 'x[7] <= 15.6\nsquared_error = 1.96\nsamples = 2\nvalue = 57.6'),
#  Text(0.006561763394279161, 0.6590909090909091, 'squared_error = 0.0\nsamples = 1\nvalue = 56.2'),
#  Text(0.008600369497356182, 0.6590909090909091, 'squared_error = 0.0\nsamples = 1\nvalue = 59.0'),
#  Text(0.015385105434159394, 0.7045454545454546, 'x[7] <= 25.15\nsquared_error = 5.116\nsamples = 21\nvalue = 64.267'),
#  Text(0.010638975600433203, 0.6590909090909091, 'x[10] <= 0.55\nsquared_error = 4.071\nsamples = 16\nvalue = 65.05'),
#  Text(0.007262534242211888, 0.6136363636363636, 'x[13] <= 0.395\nsquared_error = 2.078\nsamples = 13\nvalue = 64.369'),
#  Text(0.0035675606803847867, 0.5681818181818182, 'x[10] <= 0.3\nsquared_error = 0.023\nsamples = 2\nvalue = 61.55'),
#  Text(0.0025482576288462762, 0.5227272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 61.7'),
#  Text(0.004586863731923297, 0.5227272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 61.4'),
#  Text(0.010957507804038988, 0.5681818181818182, 'x[0] <= 2009.5\nsquared_error = 0.743\nsamples = 11\nvalue = 64.882'),
#  Text(0.006625469835000318, 0.5227272727272727, 'x[1] <= 181.0\nsquared_error = 0.217\nsamples = 6\nvalue = 64.2'),
#  Text(0.004077212206154042, 0.4772727272727273, 'x[13] <= 0.509\nsquared_error = 0.05\nsamples = 4\nvalue = 64.5'),
#  Text(0.002038606103077021, 0.4318181818181818, 'x[2] <= 366.0\nsquared_error = 0.01\nsamples = 2\nvalue = 64.3'),
#  Text(0.0010193030515385105, 0.38636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 64.2'),
#  Text(0.0030579091546155315, 0.38636363636363635, 'squared_error = -0.0\nsamples = 1\nvalue = 64.4'),
#  Text(0.006115818309231063, 0.4318181818181818, 'x[13] <= 0.514\nsquared_error = 0.01\nsamples = 2\nvalue = 64.7'),
#  Text(0.0050965152576925524, 0.38636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 64.6'),
#  Text(0.007135121360769573, 0.38636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 64.8'),
#  Text(0.009173727463846594, 0.4772727272727273, 'x[8] <= 74.0\nsquared_error = 0.01\nsamples = 2\nvalue = 63.6'),
#  Text(0.008154424412308084, 0.4318181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 63.7'),
#  Text(0.010193030515385105, 0.4318181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 63.5'),
#  Text(0.015289545773077657, 0.5227272727272727, 'x[14] <= 7.55\nsquared_error = 0.148\nsamples = 5\nvalue = 65.7'),
#  Text(0.013250939670000636, 0.4772727272727273, 'x[8] <= 78.5\nsquared_error = 0.04\nsamples = 2\nvalue = 65.3'),
#  Text(0.012231636618462126, 0.4318181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 65.5'),
#  Text(0.014270242721539147, 0.4318181818181818, 'squared_error = -0.0\nsamples = 1\nvalue = 65.1'),
#  Text(0.01732815187615468, 0.4772727272727273, 'x[11] <= 1266.866\nsquared_error = 0.042\nsamples = 3\nvalue = 65.967'),
#  Text(0.016308848824616168, 0.4318181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 65.7'),
#  Text(0.01834745492769319, 0.4318181818181818, 'x[0] <= 2013.5\nsquared_error = 0.01\nsamples = 2\nvalue = 66.1'),
#  Text(0.01732815187615468, 0.38636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 66.0'),
#  Text(0.0193667579792317, 0.38636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 66.2'),
#  Text(0.01401541695865452, 0.6136363636363636, 'x[5] <= 54.5\nsquared_error = 2.0\nsamples = 3\nvalue = 68.0'),
#  Text(0.01299611390711601, 0.5681818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 66.0'),
#  Text(0.01503472001019303, 0.5681818181818182, 'squared_error = 0.0\nsamples = 2\nvalue = 69.0'),
#  Text(0.020131235267885583, 0.6590909090909091, 'x[8] <= 57.5\nsquared_error = 0.21\nsamples = 5\nvalue = 61.76'),
#  Text(0.01809262916480856, 0.6136363636363636, 'x[13] <= 0.487\nsquared_error = 0.062\nsamples = 2\nvalue = 62.25'),
#  Text(0.017073326113270053, 0.5681818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 62.0'),
#  Text(0.019111932216347074, 0.5681818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 62.5'),
#  Text(0.022169841370962604, 0.6136363636363636, 'x[3] <= 0.015\nsquared_error = 0.042\nsamples = 3\nvalue = 61.433'),
#  Text(0.021150538319424095, 0.5681818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 61.7'),
#  Text(0.023189144422501116, 0.5681818181818182, 'x[0] <= 2007.5\nsquared_error = 0.01\nsamples = 2\nvalue = 61.3'),
#  Text(0.022169841370962604, 0.5227272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 61.2'),
#  Text(0.024208447474039625, 0.5227272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 61.4'),
#  Text(0.1218943110148436, 0.75, 'x[10] <= 0.45\nsquared_error = 9.408\nsamples = 120\nvalue = 67.537'),
#  Text(0.10028986430528126, 0.7045454545454546, 'x[3] <= 1.865\nsquared_error = 8.621\nsamples = 98\nvalue = 68.061'),
#  Text(0.08157609734344143, 0.6590909090909091, 'x[9] <= 94.5\nsquared_error = 6.481\nsamples = 80\nvalue = 67.474'),
#  Text(0.0640249729247627, 0.6136363636363636, 'x[3] <= 0.905\nsquared_error = 4.364\nsamples = 62\nvalue = 66.832'),
#  Text(0.04421226986048289, 0.5681818181818182, 'x[12] <= 107951.0\nsquared_error = 2.063\nsamples = 51\nvalue = 66.375'),
#  Text(0.026247053577116645, 0.5227272727272727, 'x[3] <= 0.205\nsquared_error = 0.456\nsamples = 15\nvalue = 65.187'),
#  Text(0.021405364082308722, 0.4772727272727273, 'x[4] <= 36.446\nsquared_error = 0.102\nsamples = 4\nvalue = 66.15'),
#  Text(0.02038606103077021, 0.4318181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 66.6'),
#  Text(0.02242466713384723, 0.4318181818181818, 'x[8] <= 85.5\nsquared_error = 0.047\nsamples = 3\nvalue = 66.0'),
#  Text(0.021405364082308722, 0.38636363636363635, 'x[11] <= 1164.131\nsquared_error = 0.002\nsamples = 2\nvalue = 66.15'),
#  Text(0.02038606103077021, 0.3409090909090909, 'squared_error = 0.0\nsamples = 1\nvalue = 66.2'),
#  Text(0.02242466713384723, 0.3409090909090909, 'squared_error = -0.0\nsamples = 1\nvalue = 66.1'),
#  Text(0.023443970185385743, 0.38636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 65.7'),
#  Text(0.031088743071924572, 0.4772727272727273, 'x[1] <= 215.5\nsquared_error = 0.124\nsamples = 11\nvalue = 64.836'),
#  Text(0.027521182391539785, 0.4318181818181818, 'x[7] <= 73.75\nsquared_error = 0.024\nsamples = 8\nvalue = 65.025'),
#  Text(0.025482576288462764, 0.38636363636363635, 'x[3] <= 0.64\nsquared_error = 0.006\nsamples = 5\nvalue = 64.92'),
#  Text(0.02446327323692425, 0.3409090909090909, 'x[14] <= 12.3\nsquared_error = 0.002\nsamples = 3\nvalue = 64.867'),
#  Text(0.023443970185385743, 0.29545454545454547, 'squared_error = 0.0\nsamples = 2\nvalue = 64.9'),
#  Text(0.025482576288462764, 0.29545454545454547, 'squared_error = 0.0\nsamples = 1\nvalue = 64.8'),
#  Text(0.026501879340001273, 0.3409090909090909, 'squared_error = 0.0\nsamples = 2\nvalue = 65.0'),
#  Text(0.029559788494616806, 0.38636363636363635, 'x[4] <= 90.253\nsquared_error = 0.007\nsamples = 3\nvalue = 65.2'),
#  Text(0.028540485443078294, 0.3409090909090909, 'squared_error = 0.0\nsamples = 1\nvalue = 65.3'),
#  Text(0.030579091546155315, 0.3409090909090909, 'x[8] <= 79.0\nsquared_error = 0.002\nsamples = 2\nvalue = 65.15'),
#  Text(0.029559788494616806, 0.29545454545454547, 'squared_error = 0.0\nsamples = 1\nvalue = 65.1'),
#  Text(0.03159839459769383, 0.29545454545454547, 'squared_error = -0.0\nsamples = 1\nvalue = 65.2'),
#  Text(0.03465630375230936, 0.4318181818181818, 'x[4] <= 65.364\nsquared_error = 0.042\nsamples = 3\nvalue = 64.333'),
#  Text(0.03363700070077085, 0.38636363636363635, 'x[5] <= 47.0\nsquared_error = 0.01\nsamples = 2\nvalue = 64.2'),
#  Text(0.032617697649232336, 0.3409090909090909, 'squared_error = 0.0\nsamples = 1\nvalue = 64.1'),
#  Text(0.03465630375230936, 0.3409090909090909, 'squared_error = 0.0\nsamples = 1\nvalue = 64.3'),
#  Text(0.03567560680384787, 0.38636363636363635, 'squared_error = -0.0\nsamples = 1\nvalue = 64.6'),
#  Text(0.062177486143849145, 0.5227272727272727, 'x[8] <= 90.5\nsquared_error = 1.899\nsamples = 36\nvalue = 66.869'),
#  Text(0.05402306173154106, 0.4772727272727273, 'x[14] <= 11.05\nsquared_error = 1.242\nsamples = 30\nvalue = 66.49'),
#  Text(0.04383003121615595, 0.4318181818181818, 'x[12] <= 604806.5\nsquared_error = 0.919\nsamples = 23\nvalue = 66.122'),
#  Text(0.0387335159584634, 0.38636363636363635, 'x[6] <= 8.5\nsquared_error = 0.582\nsamples = 5\nvalue = 67.06'),
#  Text(0.03669490985538638, 0.3409090909090909, 'x[14] <= 9.6\nsquared_error = 0.203\nsamples = 2\nvalue = 67.85'),
#  Text(0.03567560680384787, 0.29545454545454547, 'squared_error = 0.0\nsamples = 1\nvalue = 67.4'),
#  Text(0.03771421290692489, 0.29545454545454547, 'squared_error = 0.0\nsamples = 1\nvalue = 68.3'),
#  Text(0.04077212206154042, 0.3409090909090909, 'x[2] <= 25.5\nsquared_error = 0.142\nsamples = 3\nvalue = 66.533'),
#  Text(0.03975281901000191, 0.29545454545454547, 'squared_error = 0.0\nsamples = 1\nvalue = 66.0'),
#  Text(0.041791425113078935, 0.29545454545454547, 'squared_error = 0.0\nsamples = 2\nvalue = 66.8'),
#  Text(0.0489265464738485, 0.38636363636363635, 'x[5] <= 60.0\nsquared_error = 0.7\nsamples = 18\nvalue = 65.861'),
#  Text(0.04484933426769446, 0.3409090909090909, 'x[2] <= 11.5\nsquared_error = 0.18\nsamples = 3\nvalue = 64.6'),
#  Text(0.04383003121615595, 0.29545454545454547, 'squared_error = 0.0\nsamples = 1\nvalue = 65.2'),
#  Text(0.04586863731923298, 0.29545454545454547, 'squared_error = -0.0\nsamples = 2\nvalue = 64.3'),
#  Text(0.053003758680002545, 0.3409090909090909, 'x[6] <= 84.0\nsquared_error = 0.422\nsamples = 15\nvalue = 66.113'),
#  Text(0.047907243422309995, 0.29545454545454547, 'x[0] <= 2012.5\nsquared_error = 0.339\nsamples = 6\nvalue = 65.633'),
#  Text(0.045358985793463716, 0.25, 'x[14] <= 10.65\nsquared_error = 0.085\nsamples = 4\nvalue = 66.0'),
#  Text(0.0433203796903867, 0.20454545454545456, 'x[3] <= 0.33\nsquared_error = 0.023\nsamples = 2\nvalue = 65.75'),
#  Text(0.04230107663884819, 0.1590909090909091, 'squared_error = 0.0\nsamples = 1\nvalue = 65.6'),
#  Text(0.04433968274192521, 0.1590909090909091, 'squared_error = 0.0\nsamples = 1\nvalue = 65.9'),
#  Text(0.04739759189654074, 0.20454545454545456, 'x[13] <= 0.589\nsquared_error = 0.023\nsamples = 2\nvalue = 66.25'),
#  Text(0.04637828884500223, 0.1590909090909091, 'squared_error = 0.0\nsamples = 1\nvalue = 66.1'),
#  Text(0.04841689494807925, 0.1590909090909091, 'squared_error = 0.0\nsamples = 1\nvalue = 66.4'),
#  Text(0.050455501051156273, 0.25, 'x[6] <= 4.5\nsquared_error = 0.04\nsamples = 2\nvalue = 64.9'),
#  Text(0.049436197999617765, 0.20454545454545456, 'squared_error = 0.0\nsamples = 1\nvalue = 65.1'),
#  Text(0.05147480410269478, 0.20454545454545456, 'squared_error = -0.0\nsamples = 1\nvalue = 64.7'),
#  Text(0.0581002739376951, 0.29545454545454547, 'x[13] <= 0.618\nsquared_error = 0.222\nsamples = 9\nvalue = 66.433'),
#  Text(0.05708097088615659, 0.25, 'x[1] <= 188.5\nsquared_error = 0.069\nsamples = 8\nvalue = 66.575'),
#  Text(0.05351341020577181, 0.20454545454545456, 'x[8] <= 76.5\nsquared_error = 0.013\nsamples = 4\nvalue = 66.35'),
#  Text(0.05147480410269478, 0.1590909090909091, 'x[6] <= 2177.0\nsquared_error = 0.003\nsamples = 2\nvalue = 66.25'),
#  Text(0.050455501051156273, 0.11363636363636363, 'squared_error = 0.0\nsamples = 1\nvalue = 66.2'),
#  Text(0.05249410715423329, 0.11363636363636363, 'squared_error = 0.0\nsamples = 1\nvalue = 66.3'),
#  Text(0.055552016308848824, 0.1590909090909091, 'x[5] <= 75.0\nsquared_error = 0.003\nsamples = 2\nvalue = 66.45'),
#  Text(0.054532713257310315, 0.11363636363636363, 'squared_error = 0.0\nsamples = 1\nvalue = 66.5'),
#  Text(0.05657131936038733, 0.11363636363636363, 'squared_error = 0.0\nsamples = 1\nvalue = 66.4'),
#  Text(0.060648531566541375, 0.20454545454545456, 'x[4] <= 61.25\nsquared_error = 0.025\nsamples = 4\nvalue = 66.8'),
#  Text(0.059629228515002866, 0.1590909090909091, 'x[6] <= 19474.5\nsquared_error = 0.016\nsamples = 3\nvalue = 66.733'),
#  Text(0.05860992546346436, 0.11363636363636363, 'x[3] <= 0.125\nsquared_error = 0.002\nsamples = 2\nvalue = 66.65'),
#  Text(0.05759062241192585, 0.06818181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 66.7'),
#  Text(0.059629228515002866, 0.06818181818181818, 'squared_error = -0.0\nsamples = 1\nvalue = 66.6'),
#  Text(0.060648531566541375, 0.11363636363636363, 'squared_error = -0.0\nsamples = 1\nvalue = 66.9'),
#  Text(0.06166783461807989, 0.1590909090909091, 'squared_error = 0.0\nsamples = 1\nvalue = 67.0'),
#  Text(0.05911957698923361, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 65.3'),
#  Text(0.06421609224692616, 0.4318181818181818, 'x[12] <= 25160598.0\nsquared_error = 0.394\nsamples = 7\nvalue = 67.7'),
#  Text(0.06319678919538765, 0.38636363636363635, 'x[9] <= 74.5\nsquared_error = 0.18\nsamples = 6\nvalue = 67.5'),
#  Text(0.06115818309231063, 0.3409090909090909, 'x[12] <= 625557.0\nsquared_error = 0.02\nsamples = 3\nvalue = 67.1'),
#  Text(0.06013888004077212, 0.29545454545454547, 'squared_error = 0.0\nsamples = 1\nvalue = 66.9'),
#  Text(0.062177486143849145, 0.29545454545454547, 'squared_error = 0.0\nsamples = 2\nvalue = 67.2'),
#  Text(0.06523539529846467, 0.3409090909090909, 'x[12] <= 1198590.0\nsquared_error = 0.02\nsamples = 3\nvalue = 67.9'),
#  Text(0.06421609224692616, 0.29545454545454547, 'squared_error = 0.0\nsamples = 1\nvalue = 67.7'),
#  Text(0.06625469835000318, 0.29545454545454547, 'squared_error = 0.0\nsamples = 2\nvalue = 68.0'),
#  Text(0.06523539529846467, 0.38636363636363635, 'squared_error = -0.0\nsamples = 1\nvalue = 68.9'),
#  Text(0.07033191055615723, 0.4772727272727273, 'x[4] <= 53.0\nsquared_error = 0.866\nsamples = 6\nvalue = 68.767'),
#  Text(0.06829330445308021, 0.4318181818181818, 'x[5] <= 69.0\nsquared_error = 0.062\nsamples = 2\nvalue = 67.55'),
#  Text(0.0672740014015417, 0.38636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 67.8'),
#  Text(0.06931260750461872, 0.38636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 67.3'),
#  Text(0.07237051665923425, 0.4318181818181818, 'x[13] <= 0.579\nsquared_error = 0.157\nsamples = 4\nvalue = 69.375'),
#  Text(0.07135121360769574, 0.38636363636363635, 'x[13] <= 0.538\nsquared_error = 0.062\nsamples = 3\nvalue = 69.567'),
#  Text(0.07033191055615723, 0.3409090909090909, 'squared_error = 0.0\nsamples = 1\nvalue = 69.9'),
#  Text(0.07237051665923425, 0.3409090909090909, 'x[2] <= 22.0\nsquared_error = 0.01\nsamples = 2\nvalue = 69.4'),
#  Text(0.07135121360769574, 0.29545454545454547, 'squared_error = 0.0\nsamples = 1\nvalue = 69.3'),
#  Text(0.07338981971077276, 0.29545454545454547, 'squared_error = -0.0\nsamples = 1\nvalue = 69.5'),
#  Text(0.07338981971077276, 0.38636363636363635, 'squared_error = -0.0\nsamples = 1\nvalue = 68.8'),
#  Text(0.08383767598904249, 0.5681818181818182, 'x[10] <= 0.2\nsquared_error = 9.561\nsamples = 11\nvalue = 68.955'),
#  Text(0.08103459259731159, 0.5227272727272727, 'x[2] <= 4.5\nsquared_error = 4.206\nsamples = 8\nvalue = 70.512'),
#  Text(0.07848633496846531, 0.4772727272727273, 'x[13] <= 0.244\nsquared_error = 0.25\nsamples = 5\nvalue = 68.96'),
#  Text(0.0774670319169268, 0.4318181818181818, 'x[12] <= 106442.5\nsquared_error = 0.025\nsamples = 4\nvalue = 69.2'),
#  Text(0.07542842581384979, 0.38636363636363635, 'x[9] <= 39.0\nsquared_error = 0.003\nsamples = 2\nvalue = 69.05'),
#  Text(0.07440912276231126, 0.3409090909090909, 'squared_error = 0.0\nsamples = 1\nvalue = 69.1'),
#  Text(0.0764477288653883, 0.3409090909090909, 'squared_error = 0.0\nsamples = 1\nvalue = 69.0'),
#  Text(0.07950563802000382, 0.38636363636363635, 'x[3] <= 1.22\nsquared_error = 0.003\nsamples = 2\nvalue = 69.35'),
#  Text(0.07848633496846531, 0.3409090909090909, 'squared_error = 0.0\nsamples = 1\nvalue = 69.4'),
#  Text(0.08052494107154233, 0.3409090909090909, 'squared_error = 0.0\nsamples = 1\nvalue = 69.3'),
#  Text(0.07950563802000382, 0.4318181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 68.0'),
#  Text(0.08358285022615787, 0.4772727272727273, 'x[5] <= 82.0\nsquared_error = 0.087\nsamples = 3\nvalue = 73.1'),
#  Text(0.08256354717461935, 0.4318181818181818, 'x[11] <= 1258.263\nsquared_error = 0.01\nsamples = 2\nvalue = 72.9'),
#  Text(0.08154424412308084, 0.38636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 73.0'),
#  Text(0.08358285022615787, 0.38636363636363635, 'squared_error = -0.0\nsamples = 1\nvalue = 72.8'),
#  Text(0.08460215327769638, 0.4318181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 73.5'),
#  Text(0.0866407593807734, 0.5227272727272727, 'x[6] <= 38927.5\nsquared_error = 0.107\nsamples = 3\nvalue = 64.8'),
#  Text(0.08562145632923489, 0.4772727272727273, 'squared_error = 0.0\nsamples = 1\nvalue = 64.4'),
#  Text(0.0876600624323119, 0.4772727272727273, 'x[7] <= 14.15\nsquared_error = 0.04\nsamples = 2\nvalue = 65.0'),
#  Text(0.0866407593807734, 0.4318181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 64.8'),
#  Text(0.08867936548385041, 0.4318181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 65.2'),
#  Text(0.09912722176212015, 0.6136363636363636, 'x[14] <= 11.45\nsquared_error = 7.47\nsamples = 18\nvalue = 69.683'),
#  Text(0.09428553226731222, 0.5681818181818182, 'x[12] <= 426503.0\nsquared_error = 5.842\nsamples = 14\nvalue = 70.564'),
#  Text(0.09326622921577371, 0.5227272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 77.0'),
#  Text(0.09530483531885074, 0.5227272727272727, 'x[1] <= 144.5\nsquared_error = 2.861\nsamples = 13\nvalue = 70.069'),
#  Text(0.09173727463846595, 0.4772727272727273, 'x[5] <= 69.0\nsquared_error = 1.708\nsamples = 7\nvalue = 71.243'),
#  Text(0.09071797158692743, 0.4318181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 68.6'),
#  Text(0.09275657769000446, 0.4318181818181818, 'x[5] <= 97.5\nsquared_error = 0.635\nsamples = 6\nvalue = 71.683'),
#  Text(0.09173727463846595, 0.38636363636363635, 'x[0] <= 2005.0\nsquared_error = 0.134\nsamples = 5\nvalue = 71.36'),
#  Text(0.09071797158692743, 0.3409090909090909, 'squared_error = 0.0\nsamples = 1\nvalue = 72.0'),
#  Text(0.09275657769000446, 0.3409090909090909, 'x[1] <= 132.5\nsquared_error = 0.04\nsamples = 4\nvalue = 71.2'),
#  Text(0.09173727463846595, 0.29545454545454547, 'squared_error = 0.0\nsamples = 2\nvalue = 71.4'),
#  Text(0.09377588074154297, 0.29545454545454547, 'squared_error = 0.0\nsamples = 2\nvalue = 71.0'),
#  Text(0.09377588074154297, 0.38636363636363635, 'squared_error = -0.0\nsamples = 1\nvalue = 73.3'),
#  Text(0.09887239599923553, 0.4772727272727273, 'x[1] <= 164.5\nsquared_error = 0.723\nsamples = 6\nvalue = 68.7'),
#  Text(0.0968337898961585, 0.4318181818181818, 'x[5] <= 96.5\nsquared_error = 0.052\nsamples = 4\nvalue = 69.25'),
#  Text(0.09581448684461999, 0.38636363636363635, 'x[11] <= 314.996\nsquared_error = 0.016\nsamples = 3\nvalue = 69.133'),
#  Text(0.09479518379308148, 0.3409090909090909, 'squared_error = 0.0\nsamples = 1\nvalue = 69.3'),
#  Text(0.0968337898961585, 0.3409090909090909, 'x[3] <= 0.235\nsquared_error = 0.002\nsamples = 2\nvalue = 69.05'),
#  Text(0.09581448684461999, 0.29545454545454547, 'squared_error = 0.0\nsamples = 1\nvalue = 69.1'),
#  Text(0.097853092947697, 0.29545454545454547, 'squared_error = 0.0\nsamples = 1\nvalue = 69.0'),
#  Text(0.097853092947697, 0.38636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 69.6'),
#  Text(0.10091100210231255, 0.4318181818181818, 'x[5] <= 79.0\nsquared_error = 0.25\nsamples = 2\nvalue = 67.6'),
#  Text(0.09989169905077404, 0.38636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 67.1'),
#  Text(0.10193030515385106, 0.38636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 68.1'),
#  Text(0.10396891125692807, 0.5681818181818182, 'x[8] <= 97.0\nsquared_error = 0.945\nsamples = 4\nvalue = 66.6'),
#  Text(0.10193030515385106, 0.5227272727272727, 'x[0] <= 2012.0\nsquared_error = 0.022\nsamples = 2\nvalue = 65.65'),
#  Text(0.10091100210231255, 0.4772727272727273, 'squared_error = 0.0\nsamples = 1\nvalue = 65.5'),
#  Text(0.10294960820538956, 0.4772727272727273, 'squared_error = -0.0\nsamples = 1\nvalue = 65.8'),
#  Text(0.10600751736000509, 0.5227272727272727, 'x[13] <= 0.616\nsquared_error = 0.063\nsamples = 2\nvalue = 67.55'),
#  Text(0.10498821430846658, 0.4772727272727273, 'squared_error = 0.0\nsamples = 1\nvalue = 67.8'),
#  Text(0.10702682041154361, 0.4772727272727273, 'squared_error = 0.0\nsamples = 1\nvalue = 67.3'),
#  Text(0.1190036312671211, 0.6590909090909091, 'x[2] <= 5.0\nsquared_error = 9.784\nsamples = 18\nvalue = 70.672'),
#  Text(0.11467159329808244, 0.6136363636363636, 'x[3] <= 4.03\nsquared_error = 1.98\nsamples = 9\nvalue = 73.133'),
#  Text(0.11212333566923616, 0.5681818181818182, 'x[12] <= 68744.5\nsquared_error = 0.882\nsamples = 7\nvalue = 72.529'),
#  Text(0.11008472956615914, 0.5227272727272727, 'x[10] <= 0.35\nsquared_error = 0.51\nsamples = 4\nvalue = 71.9'),
#  Text(0.10906542651462063, 0.4772727272727273, 'x[3] <= 3.545\nsquared_error = 0.142\nsamples = 3\nvalue = 71.533'),
#  Text(0.10804612346308212, 0.4318181818181818, 'squared_error = 0.0\nsamples = 2\nvalue = 71.8'),
#  Text(0.11008472956615914, 0.4318181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 71.0'),
#  Text(0.11110403261769765, 0.4772727272727273, 'squared_error = 0.0\nsamples = 1\nvalue = 73.0'),
#  Text(0.11416194177231317, 0.5227272727272727, 'x[0] <= 2008.5\nsquared_error = 0.149\nsamples = 3\nvalue = 73.367'),
#  Text(0.11314263872077467, 0.4772727272727273, 'x[12] <= 2034024.0\nsquared_error = 0.01\nsamples = 2\nvalue = 73.1'),
#  Text(0.11212333566923616, 0.4318181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 73.0'),
#  Text(0.11416194177231317, 0.4318181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 73.2'),
#  Text(0.1151812448238517, 0.4772727272727273, 'squared_error = -0.0\nsamples = 1\nvalue = 73.9'),
#  Text(0.11721985092692871, 0.5681818181818182, 'x[8] <= 91.0\nsquared_error = 0.062\nsamples = 2\nvalue = 75.25'),
#  Text(0.1162005478753902, 0.5227272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 75.5'),
#  Text(0.11823915397846722, 0.5227272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 75.0'),
#  Text(0.12333566923615978, 0.6136363636363636, 'x[14] <= 10.2\nsquared_error = 5.474\nsamples = 9\nvalue = 68.211'),
#  Text(0.12129706313308275, 0.5681818181818182, 'x[8] <= 86.5\nsquared_error = 0.49\nsamples = 2\nvalue = 72.4'),
#  Text(0.12027776008154424, 0.5227272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 71.7'),
#  Text(0.12231636618462126, 0.5227272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 73.1'),
#  Text(0.12537427533923678, 0.5681818181818182, 'x[7] <= 41.05\nsquared_error = 0.453\nsamples = 7\nvalue = 67.014'),
#  Text(0.12435497228769829, 0.5227272727272727, 'x[1] <= 190.0\nsquared_error = 0.139\nsamples = 6\nvalue = 67.25'),
#  Text(0.12231636618462126, 0.4772727272727273, 'x[6] <= 16245.0\nsquared_error = 0.042\nsamples = 3\nvalue = 67.567'),
#  Text(0.12129706313308275, 0.4318181818181818, 'x[8] <= 90.0\nsquared_error = 0.01\nsamples = 2\nvalue = 67.7'),
#  Text(0.12027776008154424, 0.38636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 67.6'),
#  Text(0.12231636618462126, 0.38636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 67.8'),
#  Text(0.12333566923615978, 0.4318181818181818, 'squared_error = -0.0\nsamples = 1\nvalue = 67.3'),
#  Text(0.1263935783907753, 0.4772727272727273, 'x[2] <= 67.5\nsquared_error = 0.036\nsamples = 3\nvalue = 66.933'),
#  Text(0.12537427533923678, 0.4318181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 67.2'),
#  Text(0.12741288144231383, 0.4318181818181818, 'squared_error = -0.0\nsamples = 2\nvalue = 66.8'),
#  Text(0.1263935783907753, 0.5227272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 65.6'),
#  Text(0.14349875772440593, 0.7045454545454546, 'x[4] <= 179.441\nsquared_error = 6.226\nsamples = 22\nvalue = 65.2'),
#  Text(0.14009046314582405, 0.6590909090909091, 'x[13] <= 0.472\nsquared_error = 3.511\nsamples = 20\nvalue = 64.675'),
#  Text(0.1363317831432758, 0.6136363636363636, 'x[10] <= 1.15\nsquared_error = 1.96\nsamples = 2\nvalue = 60.0'),
#  Text(0.13531248009173727, 0.5681818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 58.6'),
#  Text(0.1373510861948143, 0.5681818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 61.4'),
#  Text(0.1438491431483723, 0.6136363636363636, 'x[0] <= 2013.0\nsquared_error = 0.985\nsamples = 18\nvalue = 65.194'),
#  Text(0.1393896922978913, 0.5681818181818182, 'x[0] <= 2007.5\nsquared_error = 0.49\nsamples = 16\nvalue = 65.456'),
#  Text(0.13352869975154488, 0.5227272727272727, 'x[4] <= 48.513\nsquared_error = 0.125\nsamples = 6\nvalue = 64.783'),
#  Text(0.13047079059692934, 0.4772727272727273, 'x[8] <= 83.0\nsquared_error = 0.042\nsamples = 3\nvalue = 64.467'),
#  Text(0.12945148754539085, 0.4318181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 64.2'),
#  Text(0.13149009364846787, 0.4318181818181818, 'x[10] <= 0.9\nsquared_error = 0.01\nsamples = 2\nvalue = 64.6'),
#  Text(0.13047079059692934, 0.38636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 64.5'),
#  Text(0.13250939670000636, 0.38636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 64.7'),
#  Text(0.13658660890616042, 0.4772727272727273, 'x[2] <= 8.5\nsquared_error = 0.007\nsamples = 3\nvalue = 65.1'),
#  Text(0.1355673058546219, 0.4318181818181818, 'x[5] <= 90.0\nsquared_error = 0.002\nsamples = 2\nvalue = 65.15'),
#  Text(0.1345480028030834, 0.38636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 65.1'),
#  Text(0.13658660890616042, 0.38636363636363635, 'squared_error = -0.0\nsamples = 1\nvalue = 65.2'),
#  Text(0.13760591195769892, 0.4318181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 65.0'),
#  Text(0.14525068484423775, 0.5227272727272727, 'x[14] <= 10.55\nsquared_error = 0.274\nsamples = 10\nvalue = 65.86'),
#  Text(0.14168312416385295, 0.4772727272727273, 'x[1] <= 26.0\nsquared_error = 0.051\nsamples = 7\nvalue = 65.557'),
#  Text(0.13964451806077594, 0.4318181818181818, 'x[9] <= 91.0\nsquared_error = 0.003\nsamples = 2\nvalue = 65.85'),
#  Text(0.13862521500923744, 0.38636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 65.9'),
#  Text(0.14066382111231446, 0.38636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 65.8'),
#  Text(0.14372173026693, 0.4318181818181818, 'x[7] <= 17.2\nsquared_error = 0.022\nsamples = 5\nvalue = 65.44'),
#  Text(0.14270242721539148, 0.38636363636363635, 'squared_error = 0.0\nsamples = 2\nvalue = 65.6'),
#  Text(0.1447410333184685, 0.38636363636363635, 'x[2] <= 50.5\nsquared_error = 0.009\nsamples = 3\nvalue = 65.333'),
#  Text(0.14372173026693, 0.3409090909090909, 'squared_error = 0.0\nsamples = 2\nvalue = 65.4'),
#  Text(0.14576033637000702, 0.3409090909090909, 'squared_error = -0.0\nsamples = 1\nvalue = 65.2'),
#  Text(0.14881824552462253, 0.4772727272727273, 'x[5] <= 97.0\nsquared_error = 0.082\nsamples = 3\nvalue = 66.567'),
#  Text(0.14779894247308403, 0.4318181818181818, 'x[5] <= 92.5\nsquared_error = 0.023\nsamples = 2\nvalue = 66.75'),
#  Text(0.1467796394215455, 0.38636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 66.6'),
#  Text(0.14881824552462253, 0.38636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 66.9'),
#  Text(0.14983754857616105, 0.4318181818181818, 'squared_error = -0.0\nsamples = 1\nvalue = 66.2'),
#  Text(0.1483085939988533, 0.5681818181818182, 'x[7] <= 13.4\nsquared_error = 0.01\nsamples = 2\nvalue = 63.1'),
#  Text(0.14728929094731477, 0.5227272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 63.0'),
#  Text(0.1493278970503918, 0.5227272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 63.2'),
#  Text(0.14690705230298784, 0.6590909090909091, 'x[14] <= 11.35\nsquared_error = 3.062\nsamples = 2\nvalue = 70.45'),
#  Text(0.14588774925144932, 0.6136363636363636, 'squared_error = 0.0\nsamples = 1\nvalue = 72.2'),
#  Text(0.14792635535452633, 0.6136363636363636, 'squared_error = 0.0\nsamples = 1\nvalue = 68.7'),
#  Text(0.171641077912977, 0.7954545454545454, 'x[1] <= 202.0\nsquared_error = 7.09\nsamples = 39\nvalue = 71.297'),
#  Text(0.162610689940753, 0.75, 'x[3] <= 1.0\nsquared_error = 4.866\nsamples = 33\nvalue = 71.991'),
#  Text(0.1549340638338536, 0.7045454545454546, 'x[4] <= 287.326\nsquared_error = 2.746\nsamples = 9\nvalue = 69.822'),
#  Text(0.15238580620500733, 0.6590909090909091, 'x[12] <= 510518.0\nsquared_error = 0.336\nsamples = 3\nvalue = 67.733'),
#  Text(0.1513665031534688, 0.6136363636363636, 'x[1] <= 97.0\nsquared_error = 0.062\nsamples = 2\nvalue = 67.35'),
#  Text(0.1503472001019303, 0.5681818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 67.6'),
#  Text(0.15238580620500733, 0.5681818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 67.1'),
#  Text(0.15340510925654582, 0.6136363636363636, 'squared_error = 0.0\nsamples = 1\nvalue = 68.5'),
#  Text(0.1574823214626999, 0.6590909090909091, 'x[8] <= 66.5\nsquared_error = 0.679\nsamples = 6\nvalue = 70.867'),
#  Text(0.15544371535962287, 0.6136363636363636, 'x[8] <= 65.5\nsquared_error = 0.072\nsamples = 4\nvalue = 71.425'),
#  Text(0.15442441230808435, 0.5681818181818182, 'x[1] <= 136.5\nsquared_error = 0.016\nsamples = 3\nvalue = 71.567'),
#  Text(0.15340510925654582, 0.5227272727272727, 'x[12] <= 139513.5\nsquared_error = 0.002\nsamples = 2\nvalue = 71.65'),
#  Text(0.15238580620500733, 0.4772727272727273, 'squared_error = 0.0\nsamples = 1\nvalue = 71.7'),
#  Text(0.15442441230808435, 0.4772727272727273, 'squared_error = -0.0\nsamples = 1\nvalue = 71.6'),
#  Text(0.15544371535962287, 0.5227272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 71.4'),
#  Text(0.15646301841116136, 0.5681818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 71.0'),
#  Text(0.1595209275657769, 0.6136363636363636, 'x[11] <= 1837.19\nsquared_error = 0.022\nsamples = 2\nvalue = 69.75'),
#  Text(0.15850162451423838, 0.5681818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 69.6'),
#  Text(0.1605402306173154, 0.5681818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 69.9'),
#  Text(0.1702873160476524, 0.7045454545454546, 'x[3] <= 5.865\nsquared_error = 3.235\nsamples = 24\nvalue = 72.804'),
#  Text(0.1670382875708734, 0.6590909090909091, 'x[13] <= 0.616\nsquared_error = 1.121\nsamples = 22\nvalue = 73.168'),
#  Text(0.16359813977193094, 0.6136363636363636, 'x[2] <= 12.0\nsquared_error = 0.896\nsamples = 17\nvalue = 72.829'),
#  Text(0.16257883672039244, 0.5681818181818182, 'x[2] <= 7.5\nsquared_error = 0.639\nsamples = 16\nvalue = 72.694'),
#  Text(0.15977575332866154, 0.5227272727272727, 'x[12] <= 3549316.5\nsquared_error = 0.445\nsamples = 14\nvalue = 72.879'),
#  Text(0.15722749569981526, 0.4772727272727273, 'x[3] <= 3.995\nsquared_error = 0.293\nsamples = 9\nvalue = 72.522'),
#  Text(0.15518888959673824, 0.4318181818181818, 'x[11] <= 1390.974\nsquared_error = 0.037\nsamples = 7\nvalue = 72.743'),
#  Text(0.15416958654519972, 0.38636363636363635, 'squared_error = 0.0\nsamples = 2\nvalue = 72.5'),
#  Text(0.15620819264827673, 0.38636363636363635, 'x[0] <= 2006.5\nsquared_error = 0.018\nsamples = 5\nvalue = 72.84'),
#  Text(0.15416958654519972, 0.3409090909090909, 'x[10] <= 0.45\nsquared_error = 0.002\nsamples = 3\nvalue = 72.733'),
#  Text(0.15315028349366122, 0.29545454545454547, 'x[13] <= 0.301\nsquared_error = 0.0\nsamples = 2\nvalue = 72.7'),
#  Text(0.1521309804421227, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 72.7'),
#  Text(0.15416958654519972, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 72.7'),
#  Text(0.15518888959673824, 0.29545454545454547, 'squared_error = -0.0\nsamples = 1\nvalue = 72.8'),
#  Text(0.15824679875135375, 0.3409090909090909, 'x[11] <= 1992.97\nsquared_error = 0.0\nsamples = 2\nvalue = 73.0'),
#  Text(0.15722749569981526, 0.29545454545454547, 'squared_error = 0.0\nsamples = 1\nvalue = 73.0'),
#  Text(0.15926610180289227, 0.29545454545454547, 'squared_error = 0.0\nsamples = 1\nvalue = 73.0'),
#  Text(0.15926610180289227, 0.4318181818181818, 'x[10] <= 0.65\nsquared_error = 0.423\nsamples = 2\nvalue = 71.75'),
#  Text(0.15824679875135375, 0.38636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 72.4'),
#  Text(0.1602854048544308, 0.38636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 71.1'),
#  Text(0.1623240109575078, 0.4772727272727273, 'x[14] <= 11.45\nsquared_error = 0.078\nsamples = 5\nvalue = 73.52'),
#  Text(0.1613047079059693, 0.4318181818181818, 'squared_error = 0.0\nsamples = 2\nvalue = 73.2'),
#  Text(0.1633433140090463, 0.4318181818181818, 'x[1] <= 12.0\nsquared_error = 0.016\nsamples = 3\nvalue = 73.733'),
#  Text(0.1623240109575078, 0.38636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 73.9'),
#  Text(0.16436261706058483, 0.38636363636363635, 'x[0] <= 2007.0\nsquared_error = 0.002\nsamples = 2\nvalue = 73.65'),
#  Text(0.1633433140090463, 0.3409090909090909, 'squared_error = 0.0\nsamples = 1\nvalue = 73.7'),
#  Text(0.16538192011212333, 0.3409090909090909, 'squared_error = -0.0\nsamples = 1\nvalue = 73.6'),
#  Text(0.16538192011212333, 0.5227272727272727, 'x[2] <= 10.5\nsquared_error = 0.09\nsamples = 2\nvalue = 71.4'),
#  Text(0.16436261706058483, 0.4772727272727273, 'squared_error = 0.0\nsamples = 1\nvalue = 71.7'),
#  Text(0.16640122316366185, 0.4772727272727273, 'squared_error = -0.0\nsamples = 1\nvalue = 71.1'),
#  Text(0.16461744282346946, 0.5681818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 75.0'),
#  Text(0.17047843536981588, 0.6136363636363636, 'x[13] <= 0.623\nsquared_error = 0.17\nsamples = 5\nvalue = 74.32'),
#  Text(0.16843982926673887, 0.5681818181818182, 'x[4] <= 502.614\nsquared_error = 0.062\nsamples = 2\nvalue = 74.75'),
#  Text(0.16742052621520034, 0.5227272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 74.5'),
#  Text(0.1694591323182774, 0.5227272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 75.0'),
#  Text(0.1725170414728929, 0.5681818181818182, 'x[3] <= 2.525\nsquared_error = 0.036\nsamples = 3\nvalue = 74.033'),
#  Text(0.1714977384213544, 0.5227272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 74.3'),
#  Text(0.17353634452443142, 0.5227272727272727, 'x[12] <= 3266732.5\nsquared_error = 0.0\nsamples = 2\nvalue = 73.9'),
#  Text(0.1725170414728929, 0.4772727272727273, 'squared_error = 0.0\nsamples = 1\nvalue = 73.9'),
#  Text(0.17455564757596992, 0.4772727272727273, 'squared_error = 0.0\nsamples = 1\nvalue = 73.9'),
#  Text(0.17353634452443142, 0.6590909090909091, 'x[11] <= 5682.394\nsquared_error = 9.0\nsamples = 2\nvalue = 68.8'),
#  Text(0.1725170414728929, 0.6136363636363636, 'squared_error = 0.0\nsamples = 1\nvalue = 65.8'),
#  Text(0.17455564757596992, 0.6136363636363636, 'squared_error = 0.0\nsamples = 1\nvalue = 71.8'),
#  Text(0.180671465885201, 0.75, 'x[14] <= 11.0\nsquared_error = 2.131\nsamples = 6\nvalue = 67.483'),
#  Text(0.17863285978212398, 0.7045454545454546, 'x[0] <= 2009.5\nsquared_error = 0.042\nsamples = 3\nvalue = 66.067'),
#  Text(0.17761355673058546, 0.6590909090909091, 'x[11] <= 2646.239\nsquared_error = 0.01\nsamples = 2\nvalue = 66.2'),
#  Text(0.17659425367904696, 0.6136363636363636, 'squared_error = 0.0\nsamples = 1\nvalue = 66.3'),
#  Text(0.17863285978212398, 0.6136363636363636, 'squared_error = 0.0\nsamples = 1\nvalue = 66.1'),
#  Text(0.17965216283366248, 0.6590909090909091, 'squared_error = -0.0\nsamples = 1\nvalue = 65.8'),
#  Text(0.18271007198827802, 0.7045454545454546, 'x[6] <= 5.0\nsquared_error = 0.207\nsamples = 3\nvalue = 68.9'),
#  Text(0.1816907689367395, 0.6590909090909091, 'x[0] <= 2007.0\nsquared_error = 0.04\nsamples = 2\nvalue = 69.2'),
#  Text(0.180671465885201, 0.6136363636363636, 'squared_error = 0.0\nsamples = 1\nvalue = 69.0'),
#  Text(0.18271007198827802, 0.6136363636363636, 'squared_error = 0.0\nsamples = 1\nvalue = 69.4'),
#  Text(0.18372937503981654, 0.6590909090909091, 'squared_error = -0.0\nsamples = 1\nvalue = 68.3'),
#  Text(0.21617984328215584, 0.8409090909090909, 'x[1] <= 267.5\nsquared_error = 11.777\nsamples = 75\nvalue = 61.397'),
#  Text(0.19260049691023762, 0.7954545454545454, 'x[14] <= 4.95\nsquared_error = 4.375\nsamples = 39\nvalue = 63.469'),
#  Text(0.18576798114289356, 0.75, 'x[10] <= 0.8\nsquared_error = 0.36\nsamples = 2\nvalue = 58.8'),
#  Text(0.18474867809135503, 0.7045454545454546, 'squared_error = 0.0\nsamples = 1\nvalue = 59.4'),
#  Text(0.18678728419443205, 0.7045454545454546, 'squared_error = 0.0\nsamples = 1\nvalue = 58.2'),
#  Text(0.1994330126775817, 0.75, 'x[9] <= 84.0\nsquared_error = 3.35\nsamples = 37\nvalue = 63.722'),
#  Text(0.18882589029750907, 0.7045454545454546, 'x[10] <= 1.25\nsquared_error = 3.008\nsamples = 22\nvalue = 63.186'),
#  Text(0.18780658724597057, 0.6590909090909091, 'x[9] <= 28.0\nsquared_error = 2.397\nsamples = 21\nvalue = 63.371'),
#  Text(0.18678728419443205, 0.6136363636363636, 'squared_error = 0.0\nsamples = 1\nvalue = 67.0'),
#  Text(0.18882589029750907, 0.6136363636363636, 'x[12] <= 275769.5\nsquared_error = 1.826\nsamples = 20\nvalue = 63.19'),
#  Text(0.18780658724597057, 0.5681818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 66.0'),
#  Text(0.1898451933490476, 0.5681818181818182, 'x[2] <= 11.5\nsquared_error = 1.485\nsamples = 19\nvalue = 63.042'),
#  Text(0.1837930814805377, 0.5227272727272727, 'x[3] <= 0.245\nsquared_error = 1.664\nsamples = 5\nvalue = 61.7'),
#  Text(0.18175447537746067, 0.4772727272727273, 'x[12] <= 634428.0\nsquared_error = 0.247\nsamples = 3\nvalue = 60.7'),
#  Text(0.18073517232592215, 0.4318181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 60.0'),
#  Text(0.18277377842899917, 0.4318181818181818, 'x[2] <= 5.5\nsquared_error = 0.003\nsamples = 2\nvalue = 61.05'),
#  Text(0.18175447537746067, 0.38636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 61.0'),
#  Text(0.1837930814805377, 0.38636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 61.1'),
#  Text(0.1858316875836147, 0.4772727272727273, 'x[9] <= 76.0\nsquared_error = 0.04\nsamples = 2\nvalue = 63.2'),
#  Text(0.18481238453207618, 0.4318181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 63.0'),
#  Text(0.1868509906351532, 0.4318181818181818, 'squared_error = -0.0\nsamples = 1\nvalue = 63.4'),
#  Text(0.1958973052175575, 0.5227272727272727, 'x[11] <= 519.865\nsquared_error = 0.547\nsamples = 14\nvalue = 63.521'),
#  Text(0.19271198318149965, 0.4772727272727273, 'x[5] <= 75.0\nsquared_error = 0.238\nsamples = 11\nvalue = 63.218'),
#  Text(0.18939924826399948, 0.4318181818181818, 'x[9] <= 71.5\nsquared_error = 0.156\nsamples = 9\nvalue = 63.367'),
#  Text(0.1858316875836147, 0.38636363636363635, 'x[12] <= 1502121.0\nsquared_error = 0.047\nsamples = 4\nvalue = 63.025'),
#  Text(0.18481238453207618, 0.3409090909090909, 'squared_error = 0.0\nsamples = 1\nvalue = 62.7'),
#  Text(0.1868509906351532, 0.3409090909090909, 'x[7] <= 17.25\nsquared_error = 0.016\nsamples = 3\nvalue = 63.133'),
#  Text(0.1858316875836147, 0.29545454545454547, 'squared_error = 0.0\nsamples = 1\nvalue = 63.3'),
#  Text(0.18787029368669173, 0.29545454545454547, 'x[8] <= 63.0\nsquared_error = 0.002\nsamples = 2\nvalue = 63.05'),
#  Text(0.1868509906351532, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 63.1'),
#  Text(0.18888959673823025, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 63.0'),
#  Text(0.19296680894438428, 0.38636363636363635, 'x[5] <= 55.0\nsquared_error = 0.074\nsamples = 5\nvalue = 63.64'),
#  Text(0.19092820284130727, 0.3409090909090909, 'x[2] <= 67.5\nsquared_error = 0.022\nsamples = 2\nvalue = 63.35'),
#  Text(0.18990889978976874, 0.29545454545454547, 'squared_error = 0.0\nsamples = 1\nvalue = 63.5'),
#  Text(0.19194750589284576, 0.29545454545454547, 'squared_error = -0.0\nsamples = 1\nvalue = 63.2'),
#  Text(0.1950054150474613, 0.3409090909090909, 'x[8] <= 73.5\nsquared_error = 0.016\nsamples = 3\nvalue = 63.833'),
#  Text(0.19398611199592278, 0.29545454545454547, 'x[4] <= 43.556\nsquared_error = 0.003\nsamples = 2\nvalue = 63.75'),
#  Text(0.19296680894438428, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 63.7'),
#  Text(0.1950054150474613, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 63.8'),
#  Text(0.1960247180989998, 0.29545454545454547, 'squared_error = 0.0\nsamples = 1\nvalue = 64.0'),
#  Text(0.1960247180989998, 0.4318181818181818, 'x[3] <= 0.795\nsquared_error = 0.063\nsamples = 2\nvalue = 62.55'),
#  Text(0.1950054150474613, 0.38636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 62.3'),
#  Text(0.19704402115053832, 0.38636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 62.8'),
#  Text(0.19908262725361534, 0.4772727272727273, 'x[14] <= 9.25\nsquared_error = 0.109\nsamples = 3\nvalue = 64.633'),
#  Text(0.19806332420207684, 0.4318181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 64.2'),
#  Text(0.20010193030515386, 0.4318181818181818, 'x[0] <= 2010.5\nsquared_error = 0.023\nsamples = 2\nvalue = 64.85'),
#  Text(0.19908262725361534, 0.38636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 64.7'),
#  Text(0.20112123335669235, 0.38636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 65.0'),
#  Text(0.1898451933490476, 0.6590909090909091, 'squared_error = 0.0\nsamples = 1\nvalue = 59.3'),
#  Text(0.21004013505765434, 0.7045454545454546, 'x[8] <= 8.5\nsquared_error = 2.817\nsamples = 15\nvalue = 64.507'),
#  Text(0.20902083200611582, 0.6590909090909091, 'squared_error = 0.0\nsamples = 1\nvalue = 69.0'),
#  Text(0.21105943810919284, 0.6590909090909091, 'x[12] <= 2703.5\nsquared_error = 1.473\nsamples = 14\nvalue = 64.186'),
#  Text(0.21004013505765434, 0.6136363636363636, 'squared_error = 0.0\nsamples = 1\nvalue = 67.0'),
#  Text(0.21207874116073136, 0.6136363636363636, 'x[13] <= 0.488\nsquared_error = 0.93\nsamples = 13\nvalue = 63.969'),
#  Text(0.20672740014015417, 0.5681818181818182, 'x[3] <= 0.845\nsquared_error = 0.573\nsamples = 9\nvalue = 64.4'),
#  Text(0.2041791425113079, 0.5227272727272727, 'x[7] <= 27.3\nsquared_error = 0.116\nsamples = 3\nvalue = 65.333'),
#  Text(0.20315983945976937, 0.4772727272727273, 'x[1] <= 243.5\nsquared_error = 0.01\nsamples = 2\nvalue = 65.1'),
#  Text(0.20214053640823088, 0.4318181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 65.2'),
#  Text(0.2041791425113079, 0.4318181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 65.0'),
#  Text(0.20519844556284642, 0.4772727272727273, 'squared_error = -0.0\nsamples = 1\nvalue = 65.8'),
#  Text(0.20927565776900045, 0.5227272727272727, 'x[11] <= 505.893\nsquared_error = 0.149\nsamples = 6\nvalue = 63.933'),
#  Text(0.20723705166592343, 0.4772727272727273, 'x[4] <= 18.413\nsquared_error = 0.029\nsamples = 3\nvalue = 64.267'),
#  Text(0.2062177486143849, 0.4318181818181818, 'x[8] <= 53.5\nsquared_error = 0.003\nsamples = 2\nvalue = 64.15'),
#  Text(0.20519844556284642, 0.38636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 64.2'),
#  Text(0.20723705166592343, 0.38636363636363635, 'squared_error = -0.0\nsamples = 1\nvalue = 64.1'),
#  Text(0.20825635471746193, 0.4318181818181818, 'squared_error = -0.0\nsamples = 1\nvalue = 64.5'),
#  Text(0.21131426387207747, 0.4772727272727273, 'x[0] <= 2004.0\nsquared_error = 0.047\nsamples = 3\nvalue = 63.6'),
#  Text(0.21029496082053895, 0.4318181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 63.3'),
#  Text(0.212333566923616, 0.4318181818181818, 'x[2] <= 10.0\nsquared_error = 0.002\nsamples = 2\nvalue = 63.75'),
#  Text(0.21131426387207747, 0.38636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 63.7'),
#  Text(0.21335286997515449, 0.38636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 63.8'),
#  Text(0.21743008218130852, 0.5681818181818182, 'x[12] <= 14703111.5\nsquared_error = 0.375\nsamples = 4\nvalue = 63.0'),
#  Text(0.21641077912977003, 0.5227272727272727, 'x[7] <= 39.45\nsquared_error = 0.14\nsamples = 3\nvalue = 63.3'),
#  Text(0.2153914760782315, 0.4772727272727273, 'x[8] <= 90.0\nsquared_error = 0.023\nsamples = 2\nvalue = 63.05'),
#  Text(0.214372173026693, 0.4318181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 62.9'),
#  Text(0.21641077912977003, 0.4318181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 63.2'),
#  Text(0.21743008218130852, 0.4772727272727273, 'squared_error = 0.0\nsamples = 1\nvalue = 63.8'),
#  Text(0.21844938523284704, 0.5227272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 62.1'),
#  Text(0.23975918965407403, 0.7954545454545454, 'x[1] <= 373.0\nsquared_error = 10.106\nsamples = 36\nvalue = 59.153'),
#  Text(0.2334203988023189, 0.75, 'x[2] <= 12.0\nsquared_error = 4.645\nsamples = 34\nvalue = 59.732'),
#  Text(0.22380072625342423, 0.7045454545454546, 'x[8] <= 57.5\nsquared_error = 3.174\nsamples = 14\nvalue = 61.586'),
#  Text(0.21946868828438554, 0.6590909090909091, 'x[9] <= 6.5\nsquared_error = 0.376\nsamples = 3\nvalue = 58.867'),
#  Text(0.21844938523284704, 0.6136363636363636, 'squared_error = 0.0\nsamples = 1\nvalue = 58.1'),
#  Text(0.22048799133592406, 0.6136363636363636, 'x[12] <= 3077716.5\nsquared_error = 0.123\nsamples = 2\nvalue = 59.25'),
#  Text(0.21946868828438554, 0.5681818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 59.6'),
#  Text(0.22150729438746258, 0.5681818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 58.9'),
#  Text(0.2281327642224629, 0.6590909090909091, 'x[9] <= 93.0\nsquared_error = 1.371\nsamples = 11\nvalue = 62.327'),
#  Text(0.2245652035420781, 0.6136363636363636, 'x[1] <= 273.5\nsquared_error = 0.72\nsamples = 7\nvalue = 61.643'),
#  Text(0.2235459004905396, 0.5681818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 59.8'),
#  Text(0.22558450659361662, 0.5681818181818182, 'x[14] <= 9.75\nsquared_error = 0.179\nsamples = 6\nvalue = 61.95'),
#  Text(0.2235459004905396, 0.5227272727272727, 'x[7] <= 14.7\nsquared_error = 0.05\nsamples = 4\nvalue = 61.7'),
#  Text(0.22252659743900108, 0.4772727272727273, 'squared_error = 0.0\nsamples = 1\nvalue = 62.0'),
#  Text(0.2245652035420781, 0.4772727272727273, 'x[13] <= 0.44\nsquared_error = 0.027\nsamples = 3\nvalue = 61.6'),
#  Text(0.2235459004905396, 0.4318181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 61.4'),
#  Text(0.22558450659361662, 0.4318181818181818, 'x[13] <= 0.481\nsquared_error = 0.01\nsamples = 2\nvalue = 61.7'),
#  Text(0.2245652035420781, 0.38636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 61.6'),
#  Text(0.2266038096451551, 0.38636363636363635, 'squared_error = -0.0\nsamples = 1\nvalue = 61.8'),
#  Text(0.22762311269669364, 0.5227272727272727, 'x[0] <= 2013.0\nsquared_error = 0.062\nsamples = 2\nvalue = 62.45'),
#  Text(0.2266038096451551, 0.4772727272727273, 'squared_error = 0.0\nsamples = 1\nvalue = 62.2'),
#  Text(0.22864241574823216, 0.4772727272727273, 'squared_error = 0.0\nsamples = 1\nvalue = 62.7'),
#  Text(0.23170032490284767, 0.6136363636363636, 'x[13] <= 0.596\nsquared_error = 0.257\nsamples = 4\nvalue = 63.525'),
#  Text(0.23068102185130918, 0.5681818181818182, 'x[12] <= 1510435.0\nsquared_error = 0.062\nsamples = 2\nvalue = 63.05'),
#  Text(0.22966171879977065, 0.5227272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 63.3'),
#  Text(0.23170032490284767, 0.5227272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 62.8'),
#  Text(0.2327196279543862, 0.5681818181818182, 'squared_error = -0.0\nsamples = 2\nvalue = 64.0'),
#  Text(0.2430400713512136, 0.7045454545454546, 'x[13] <= 0.383\nsquared_error = 1.587\nsamples = 20\nvalue = 58.435'),
#  Text(0.23679684016054023, 0.6590909090909091, 'x[1] <= 305.5\nsquared_error = 0.472\nsamples = 4\nvalue = 56.475'),
#  Text(0.23577753710900173, 0.6136363636363636, 'x[3] <= 0.015\nsquared_error = 0.016\nsamples = 3\nvalue = 56.867'),
#  Text(0.2347582340574632, 0.5681818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 56.7'),
#  Text(0.23679684016054023, 0.5681818181818182, 'x[7] <= 14.95\nsquared_error = 0.003\nsamples = 2\nvalue = 56.95'),
#  Text(0.23577753710900173, 0.5227272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 57.0'),
# ...
#  Text(0.48142957252978275, 0.4772727272727273, 'x[6] <= 3736.0\nsquared_error = 0.238\nsamples = 5\nvalue = 68.52'),
#  Text(0.47939096642670576, 0.4318181818181818, 'x[5] <= 50.0\nsquared_error = 0.08\nsamples = 3\nvalue = 68.2'),
#  Text(0.47837166337516723, 0.38636363636363635, 'squared_error = 0.0\nsamples = 2\nvalue = 68.4'),
#  Text(0.4804102694782442, 0.38636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 67.8'),
#  Text(0.4834681786328598, 0.4318181818181818, 'x[6] <= 6956.5\nsquared_error = 0.09\nsamples = 2\nvalue = 69.0'),
#  Text(0.48244887558132127, 0.38636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 69.3'),
#  Text(0.4844874816843983, 0.38636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 68.7'),
#  Text(0.4865260877874753, 0.4772727272727273, 'x[8] <= 84.5\nsquared_error = 0.49\nsamples = 2\nvalue = 72.2'),
#  Text(0.4855067847359368, 0.4318181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 71.5'),
#  Text(0.4875453908390138, 0.4318181818181818, 'squared_error = -0.0\nsamples = 1\nvalue = 72.9'),
#  Text(0.5077721857679811, 0.5681818181818182, 'x[1] <= 63.0\nsquared_error = 3.233\nsamples = 43\nvalue = 72.56'),
#  Text(0.496973944065745, 0.5227272727272727, 'x[1] <= 20.0\nsquared_error = 6.319\nsamples = 14\nvalue = 71.579'),
#  Text(0.4921322545709371, 0.4772727272727273, 'x[3] <= 0.81\nsquared_error = 0.291\nsamples = 9\nvalue = 73.244'),
#  Text(0.48958399694209087, 0.4318181818181818, 'x[11] <= 3078.889\nsquared_error = 0.062\nsamples = 2\nvalue = 72.55'),
#  Text(0.48856469389055235, 0.38636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 72.3'),
#  Text(0.49060329999362934, 0.38636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 72.8'),
#  Text(0.4946805121997834, 0.4318181818181818, 'x[14] <= 13.4\nsquared_error = 0.18\nsamples = 7\nvalue = 73.443'),
#  Text(0.4926419060967064, 0.38636363636363635, 'x[11] <= 234.412\nsquared_error = 0.082\nsamples = 5\nvalue = 73.24'),
#  Text(0.49162260304516786, 0.3409090909090909, 'squared_error = 0.0\nsamples = 1\nvalue = 72.8'),
#  Text(0.4936612091482449, 0.3409090909090909, 'x[8] <= 97.5\nsquared_error = 0.043\nsamples = 4\nvalue = 73.35'),
#  Text(0.4926419060967064, 0.29545454545454547, 'x[4] <= 367.506\nsquared_error = 0.002\nsamples = 3\nvalue = 73.467'),
#  Text(0.49162260304516786, 0.25, 'squared_error = 0.0\nsamples = 2\nvalue = 73.5'),
#  Text(0.4936612091482449, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 73.4'),
#  Text(0.4946805121997834, 0.29545454545454547, 'squared_error = 0.0\nsamples = 1\nvalue = 73.0'),
#  Text(0.4967191183028604, 0.38636363636363635, 'x[3] <= 1.355\nsquared_error = 0.062\nsamples = 2\nvalue = 73.95'),
#  Text(0.4956998152513219, 0.3409090909090909, 'squared_error = 0.0\nsamples = 1\nvalue = 73.7'),
#  Text(0.49773842135439894, 0.3409090909090909, 'squared_error = 0.0\nsamples = 1\nvalue = 74.2'),
#  Text(0.5018156335605529, 0.4772727272727273, 'x[6] <= 6.0\nsquared_error = 3.182\nsamples = 5\nvalue = 68.58'),
#  Text(0.49977702745747593, 0.4318181818181818, 'x[10] <= 0.35\nsquared_error = 1.5\nsamples = 3\nvalue = 69.7'),
#  Text(0.49875772440593746, 0.38636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 71.2'),
#  Text(0.5007963305090145, 0.38636363636363635, 'x[11] <= 3550.438\nsquared_error = 0.562\nsamples = 2\nvalue = 68.95'),
#  Text(0.49977702745747593, 0.3409090909090909, 'squared_error = 0.0\nsamples = 1\nvalue = 68.2'),
#  Text(0.5018156335605529, 0.3409090909090909, 'squared_error = 0.0\nsamples = 1\nvalue = 69.7'),
#  Text(0.50385423966363, 0.4318181818181818, 'x[2] <= 1.0\nsquared_error = 1.0\nsamples = 2\nvalue = 66.9'),
#  Text(0.5028349366120914, 0.38636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 67.9'),
#  Text(0.5048735427151685, 0.38636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 65.9'),
#  Text(0.5185704274702172, 0.5227272727272727, 'x[7] <= 66.8\nsquared_error = 1.053\nsamples = 29\nvalue = 73.034'),
#  Text(0.5175511244186787, 0.4772727272727273, 'x[2] <= 107.0\nsquared_error = 0.766\nsamples = 28\nvalue = 72.929'),
#  Text(0.512390902720265, 0.4318181818181818, 'x[4] <= 437.883\nsquared_error = 0.554\nsamples = 25\nvalue = 72.756'),
#  Text(0.5071669745811301, 0.38636363636363635, 'x[3] <= 4.265\nsquared_error = 0.402\nsamples = 19\nvalue = 72.505'),
#  Text(0.50385423966363, 0.3409090909090909, 'x[4] <= 300.17\nsquared_error = 0.193\nsamples = 11\nvalue = 72.845'),
#  Text(0.5028349366120914, 0.29545454545454547, 'x[13] <= 0.674\nsquared_error = 0.092\nsamples = 10\nvalue = 72.95'),
#  Text(0.5002866789832452, 0.25, 'x[11] <= 714.205\nsquared_error = 0.019\nsamples = 8\nvalue = 72.812'),
#  Text(0.4982480728801682, 0.20454545454545456, 'x[8] <= 96.5\nsquared_error = 0.005\nsamples = 4\nvalue = 72.7'),
#  Text(0.4972287698286297, 0.1590909090909091, 'x[2] <= 8.5\nsquared_error = 0.002\nsamples = 3\nvalue = 72.733'),
#  Text(0.49620946677709116, 0.11363636363636363, 'x[0] <= 2007.5\nsquared_error = 0.0\nsamples = 2\nvalue = 72.7'),
#  Text(0.49519016372555263, 0.06818181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 72.7'),
#  Text(0.4972287698286297, 0.06818181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 72.7'),
#  Text(0.4982480728801682, 0.11363636363636363, 'squared_error = -0.0\nsamples = 1\nvalue = 72.8'),
#  Text(0.49926737593170667, 0.1590909090909091, 'squared_error = 0.0\nsamples = 1\nvalue = 72.6'),
#  Text(0.5023252850863222, 0.20454545454545456, 'x[12] <= 4871530.5\nsquared_error = 0.007\nsamples = 4\nvalue = 72.925'),
#  Text(0.5013059820347837, 0.1590909090909091, 'squared_error = 0.0\nsamples = 2\nvalue = 73.0'),
#  Text(0.5033445881378608, 0.1590909090909091, 'x[6] <= 23.5\nsquared_error = 0.003\nsamples = 2\nvalue = 72.85'),
#  Text(0.5023252850863222, 0.11363636363636363, 'squared_error = 0.0\nsamples = 1\nvalue = 72.8'),
#  Text(0.5043638911893993, 0.11363636363636363, 'squared_error = 0.0\nsamples = 1\nvalue = 72.9'),
#  Text(0.5053831942409378, 0.25, 'x[0] <= 2004.0\nsquared_error = 0.01\nsamples = 2\nvalue = 73.5'),
#  Text(0.5043638911893993, 0.20454545454545456, 'squared_error = 0.0\nsamples = 1\nvalue = 73.6'),
#  Text(0.5064024972924762, 0.20454545454545456, 'squared_error = 0.0\nsamples = 1\nvalue = 73.4'),
#  Text(0.5048735427151685, 0.29545454545454547, 'squared_error = 0.0\nsamples = 1\nvalue = 71.8'),
#  Text(0.5104797094986303, 0.3409090909090909, 'x[10] <= 0.15\nsquared_error = 0.31\nsamples = 8\nvalue = 72.038'),
#  Text(0.5084411033955533, 0.29545454545454547, 'x[5] <= 91.5\nsquared_error = 0.062\nsamples = 2\nvalue = 71.25'),
#  Text(0.5074218003440147, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 71.0'),
#  Text(0.5094604064470918, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 71.5'),
#  Text(0.5125183156017074, 0.29545454545454547, 'x[5] <= 94.0\nsquared_error = 0.117\nsamples = 6\nvalue = 72.3'),
#  Text(0.5114990125501688, 0.25, 'x[5] <= 74.5\nsquared_error = 0.022\nsamples = 5\nvalue = 72.16'),
#  Text(0.5094604064470918, 0.20454545454545456, 'x[4] <= 27.652\nsquared_error = 0.01\nsamples = 2\nvalue = 72.0'),
#  Text(0.5084411033955533, 0.1590909090909091, 'squared_error = 0.0\nsamples = 1\nvalue = 71.9'),
#  Text(0.5104797094986303, 0.1590909090909091, 'squared_error = 0.0\nsamples = 1\nvalue = 72.1'),
#  Text(0.5135376186532459, 0.20454545454545456, 'x[0] <= 2005.0\nsquared_error = 0.002\nsamples = 3\nvalue = 72.267'),
#  Text(0.5125183156017074, 0.1590909090909091, 'squared_error = 0.0\nsamples = 1\nvalue = 72.2'),
#  Text(0.5145569217047844, 0.1590909090909091, 'squared_error = -0.0\nsamples = 2\nvalue = 72.3'),
#  Text(0.5135376186532459, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 73.0'),
#  Text(0.5176148308593999, 0.38636363636363635, 'x[12] <= 2552770.5\nsquared_error = 0.206\nsamples = 6\nvalue = 73.55'),
#  Text(0.5165955278078613, 0.3409090909090909, 'squared_error = 0.0\nsamples = 1\nvalue = 74.5'),
#  Text(0.5186341339109384, 0.3409090909090909, 'x[5] <= 92.5\nsquared_error = 0.03\nsamples = 5\nvalue = 73.36'),
#  Text(0.5165955278078613, 0.29545454545454547, 'x[13] <= 0.681\nsquared_error = 0.002\nsamples = 2\nvalue = 73.55'),
#  Text(0.5155762247563228, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 73.6'),
#  Text(0.5176148308593999, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 73.5'),
#  Text(0.5206727400140154, 0.29545454545454547, 'x[7] <= 15.05\nsquared_error = 0.009\nsamples = 3\nvalue = 73.233'),
#  Text(0.5196534369624769, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 73.1'),
#  Text(0.521692043065554, 0.25, 'squared_error = 0.0\nsamples = 2\nvalue = 73.3'),
#  Text(0.5227113461170925, 0.4318181818181818, 'x[14] <= 12.55\nsquared_error = 0.216\nsamples = 3\nvalue = 74.367'),
#  Text(0.521692043065554, 0.38636363636363635, 'x[7] <= 24.5\nsquared_error = 0.023\nsamples = 2\nvalue = 74.05'),
#  Text(0.5206727400140154, 0.3409090909090909, 'squared_error = 0.0\nsamples = 1\nvalue = 73.9'),
#  Text(0.5227113461170925, 0.3409090909090909, 'squared_error = -0.0\nsamples = 1\nvalue = 74.2'),
#  Text(0.523730649168631, 0.38636363636363635, 'squared_error = -0.0\nsamples = 1\nvalue = 75.0'),
#  Text(0.5195897305217557, 0.4772727272727273, 'squared_error = 0.0\nsamples = 1\nvalue = 76.0'),
#  Text(0.5378575523985475, 0.6136363636363636, 'x[12] <= 110551.0\nsquared_error = 2.023\nsamples = 31\nvalue = 73.271'),
#  Text(0.5303561190036312, 0.5681818181818182, 'x[5] <= 93.5\nsquared_error = 2.68\nsamples = 9\nvalue = 71.978'),
#  Text(0.527807861374785, 0.5227272727272727, 'x[3] <= 0.465\nsquared_error = 0.45\nsamples = 7\nvalue = 72.786'),
#  Text(0.5257692552717079, 0.4772727272727273, 'x[4] <= 509.338\nsquared_error = 0.01\nsamples = 2\nvalue = 73.7'),
#  Text(0.5247499522201695, 0.4318181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 73.8'),
#  Text(0.5267885583232464, 0.4318181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 73.6'),
#  Text(0.529846467477862, 0.4772727272727273, 'x[11] <= 1908.094\nsquared_error = 0.158\nsamples = 5\nvalue = 72.42'),
#  Text(0.5288271644263235, 0.4318181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 71.7'),
#  Text(0.5308657705294005, 0.4318181818181818, 'x[12] <= 24105.0\nsquared_error = 0.035\nsamples = 4\nvalue = 72.6'),
#  Text(0.529846467477862, 0.38636363636363635, 'x[11] <= 2912.419\nsquared_error = 0.007\nsamples = 3\nvalue = 72.5'),
#  Text(0.5288271644263235, 0.3409090909090909, 'squared_error = 0.0\nsamples = 1\nvalue = 72.4'),
#  Text(0.5308657705294005, 0.3409090909090909, 'x[6] <= 4.0\nsquared_error = 0.002\nsamples = 2\nvalue = 72.55'),
#  Text(0.529846467477862, 0.29545454545454547, 'squared_error = 0.0\nsamples = 1\nvalue = 72.5'),
#  Text(0.5318850735809391, 0.29545454545454547, 'squared_error = -0.0\nsamples = 1\nvalue = 72.6'),
#  Text(0.5318850735809391, 0.38636363636363635, 'squared_error = -0.0\nsamples = 1\nvalue = 72.9'),
#  Text(0.5329043766324776, 0.5227272727272727, 'x[4] <= 66.149\nsquared_error = 0.202\nsamples = 2\nvalue = 69.15'),
#  Text(0.5318850735809391, 0.4772727272727273, 'squared_error = 0.0\nsamples = 1\nvalue = 69.6'),
#  Text(0.5339236796840161, 0.4772727272727273, 'squared_error = -0.0\nsamples = 1\nvalue = 68.7'),
#  Text(0.5453589857934638, 0.5681818181818182, 'x[12] <= 230483.5\nsquared_error = 0.791\nsamples = 22\nvalue = 73.8'),
#  Text(0.5406765624004587, 0.5227272727272727, 'x[14] <= 12.25\nsquared_error = 0.25\nsamples = 2\nvalue = 75.5'),
#  Text(0.5396572593489202, 0.4772727272727273, 'squared_error = 0.0\nsamples = 1\nvalue = 75.0'),
#  Text(0.5416958654519972, 0.4772727272727273, 'squared_error = 0.0\nsamples = 1\nvalue = 76.0'),
#  Text(0.5500414091864687, 0.5227272727272727, 'x[3] <= 5.97\nsquared_error = 0.527\nsamples = 20\nvalue = 73.63'),
#  Text(0.5437344715550743, 0.4772727272727273, 'x[1] <= 147.5\nsquared_error = 0.337\nsamples = 15\nvalue = 73.887'),
#  Text(0.5402943237561317, 0.4318181818181818, 'x[12] <= 36683062.0\nsquared_error = 0.202\nsamples = 10\nvalue = 74.14'),
#  Text(0.5374912403644009, 0.38636363636363635, 'x[9] <= 95.0\nsquared_error = 0.072\nsamples = 8\nvalue = 74.325'),
#  Text(0.5349429827355545, 0.3409090909090909, 'x[4] <= 505.268\nsquared_error = 0.016\nsamples = 3\nvalue = 74.067'),
#  Text(0.5339236796840161, 0.29545454545454547, 'x[10] <= 0.25\nsquared_error = 0.002\nsamples = 2\nvalue = 74.15'),
#  Text(0.5329043766324776, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 74.1'),
#  Text(0.5349429827355545, 0.25, 'squared_error = -0.0\nsamples = 1\nvalue = 74.2'),
#  Text(0.535962285787093, 0.29545454545454547, 'squared_error = 0.0\nsamples = 1\nvalue = 73.9'),
#  Text(0.5400394979932471, 0.3409090909090909, 'x[12] <= 7356110.0\nsquared_error = 0.042\nsamples = 5\nvalue = 74.48'),
#  Text(0.5380008918901701, 0.29545454545454547, 'x[12] <= 2194647.5\nsquared_error = 0.009\nsamples = 3\nvalue = 74.333'),
#  Text(0.5369815888386316, 0.25, 'squared_error = 0.0\nsamples = 2\nvalue = 74.4'),
#  Text(0.5390201949417086, 0.25, 'squared_error = -0.0\nsamples = 1\nvalue = 74.2'),
#  Text(0.5420781040963242, 0.29545454545454547, 'x[2] <= 31.0\nsquared_error = 0.01\nsamples = 2\nvalue = 74.7'),
#  Text(0.5410588010447857, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 74.6'),
#  Text(0.5430974071478627, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 74.8'),
#  Text(0.5430974071478627, 0.38636363636363635, 'x[14] <= 12.35\nsquared_error = 0.04\nsamples = 2\nvalue = 73.4'),
#  Text(0.5420781040963242, 0.3409090909090909, 'squared_error = 0.0\nsamples = 1\nvalue = 73.2'),
#  Text(0.5441167101994011, 0.3409090909090909, 'squared_error = -0.0\nsamples = 1\nvalue = 73.6'),
#  Text(0.5471746193540167, 0.4318181818181818, 'x[4] <= 86.841\nsquared_error = 0.222\nsamples = 5\nvalue = 73.38'),
#  Text(0.5461553163024782, 0.38636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 74.2'),
#  Text(0.5481939224055552, 0.38636363636363635, 'x[5] <= 96.0\nsquared_error = 0.067\nsamples = 4\nvalue = 73.175'),
#  Text(0.5461553163024782, 0.3409090909090909, 'x[11] <= 3110.002\nsquared_error = 0.023\nsamples = 2\nvalue = 72.95'),
#  Text(0.5451360132509396, 0.29545454545454547, 'squared_error = 0.0\nsamples = 1\nvalue = 72.8'),
#  Text(0.5471746193540167, 0.29545454545454547, 'squared_error = 0.0\nsamples = 1\nvalue = 73.1'),
#  Text(0.5502325285086322, 0.3409090909090909, 'x[10] <= 1.3\nsquared_error = 0.01\nsamples = 2\nvalue = 73.4'),
#  Text(0.5492132254570937, 0.29545454545454547, 'squared_error = 0.0\nsamples = 1\nvalue = 73.5'),
#  Text(0.5512518315601708, 0.29545454545454547, 'squared_error = -0.0\nsamples = 1\nvalue = 73.3'),
#  Text(0.5563483468178633, 0.4772727272727273, 'x[10] <= 1.05\nsquared_error = 0.306\nsamples = 5\nvalue = 72.86'),
#  Text(0.5543097407147862, 0.4318181818181818, 'x[2] <= 78.0\nsquared_error = 0.109\nsamples = 3\nvalue = 72.467'),
#  Text(0.5532904376632477, 0.38636363636363635, 'x[13] <= 0.696\nsquared_error = 0.0\nsamples = 2\nvalue = 72.7'),
#  Text(0.5522711346117093, 0.3409090909090909, 'squared_error = 0.0\nsamples = 1\nvalue = 72.7'),
#  Text(0.5543097407147862, 0.3409090909090909, 'squared_error = 0.0\nsamples = 1\nvalue = 72.7'),
#  Text(0.5553290437663247, 0.38636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 72.0'),
#  Text(0.5583869529209403, 0.4318181818181818, 'x[5] <= 44.5\nsquared_error = 0.022\nsamples = 2\nvalue = 73.45'),
#  Text(0.5573676498694018, 0.38636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 73.6'),
#  Text(0.5594062559724788, 0.38636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 73.3'),
#  Text(0.6749239504363891, 0.75, 'x[1] <= 127.5\nsquared_error = 4.957\nsamples = 202\nvalue = 74.555'),
#  Text(0.6249960183474549, 0.7045454545454546, 'x[10] <= 0.25\nsquared_error = 6.206\nsamples = 123\nvalue = 75.172'),
#  Text(0.5963639548958399, 0.6590909090909091, 'x[3] <= 2.795\nsquared_error = 4.572\nsamples = 119\nvalue = 75.391'),
#  Text(0.5725934892017583, 0.6136363636363636, 'x[3] <= 1.85\nsquared_error = 2.257\nsamples = 37\nvalue = 74.011'),
#  Text(0.5705548830986813, 0.5681818181818182, 'x[14] <= 15.15\nsquared_error = 1.405\nsamples = 35\nvalue = 74.234'),
#  ...]

# %% [markdown]
# What can you observe from this tree? If you set the `max_depth = 3`, is it consistant with what you find in problem 1.1b?

# %%
dtree = tree.DecisionTreeRegressor(max_depth=3)

### Your code starts here. Fit the tree and plot again!
dtree = dtree.fit(X_train, y_train)
plt.figure(figsize=(10, 10))
tree.plot_tree(dtree)
# Out:
# [Text(0.5, 0.875, 'x[13] <= 0.632\nsquared_error = 75.94\nsamples = 989\nvalue = 68.982'),
#  Text(0.25, 0.625, 'x[10] <= 1.35\nsquared_error = 53.539\nsamples = 426\nvalue = 61.812'),
#  Text(0.375, 0.75, 'True  '),
#  Text(0.125, 0.375, 'x[1] <= 227.5\nsquared_error = 21.676\nsamples = 257\nvalue = 65.971'),
#  Text(0.0625, 0.125, 'squared_error = 13.582\nsamples = 182\nvalue = 67.856'),
#  Text(0.1875, 0.125, 'squared_error = 11.777\nsamples = 75\nvalue = 61.397'),
#  Text(0.375, 0.375, 'x[10] <= 7.35\nsquared_error = 35.688\nsamples = 169\nvalue = 55.488'),
#  Text(0.3125, 0.125, 'squared_error = 27.856\nsamples = 108\nvalue = 58.103'),
#  Text(0.4375, 0.125, 'squared_error = 16.007\nsamples = 61\nvalue = 50.857'),
#  Text(0.75, 0.625, 'x[13] <= 0.802\nsquared_error = 24.563\nsamples = 563\nvalue = 74.407'),
#  Text(0.625, 0.75, '  False'),
#  Text(0.625, 0.375, 'x[1] <= 183.5\nsquared_error = 13.742\nsamples = 412\nvalue = 72.377'),
#  Text(0.5625, 0.125, 'squared_error = 7.548\nsamples = 307\nvalue = 73.745'),
#  Text(0.6875, 0.125, 'squared_error = 10.386\nsamples = 105\nvalue = 68.377'),
#  Text(0.875, 0.375, 'x[1] <= 109.0\nsquared_error = 12.155\nsamples = 151\nvalue = 79.946'),
#  Text(0.8125, 0.125, 'squared_error = 8.372\nsamples = 132\nvalue = 80.748'),
#  Text(0.9375, 0.125, 'squared_error = 2.975\nsamples = 19\nvalue = 74.379')]

# %% [markdown]
# Setting max depth to 3, we see that the results are the same as 1.1b. The first split corresponds to splitting for the income parameter at 0.632. The second splits also correspond to what we found with splitting the left tree according to HIV at 1.35 and the right tree according to income again at 0.802.

# %% [markdown]
# ### 1.3 Evaluation of your tree
#
# Evaluate your regression tree with the test dataset. What is the R-squared and the MSE of the model using the test set? The `.predict` method for your model can help with this.

# %%
# Making predictions on the test dataset
### Your code starts here
predictions = my_tree.predict(X_test)
print(predictions)
# Out:
# [69.5 73.7 79.4 54.8 49.8 51.5 69.  74.9 76.  73.4 71.6 75.8 79.7 68.
#  75.  69.  72.1 81.1 78.5 75.  85.  68.7 73.  78.5 67.  67.3 75.4 78.8
#  81.7 74.6 56.2 56.  71.7 81.8 79.5 79.3 56.9 53.  73.  77.3 59.2 75.8
#  72.1 73.5 83.  58.3 74.2 62.  74.5 73.9 65.  63.2 56.6 74.5 72.4 59.6
#  74.6 74.7 74.4 58.6 55.3 55.8 65.4 71.6 74.2 72.9 56.5 73.6 79.3 68.9
#  72.2 71.6 59.2 45.3 74.4 67.9 66.1 57.2 75.  78.  73.7 72.2 73.6 73.8
#  58.  72.2 71.5 67.3 71.1 71.4 76.  74.9 67.3 72.7 84.  72.4 64.1 68.2
#  77.5 73.  73.  73.1 68.9 61.7 78.2 74.1 75.6 75.8 65.  72.2 69.5 73.3
#  79.1 71.1 75.7 74.7 51.4 67.7 73.  68.5 69.2 49.8 48.2 75.7 71.7 86.
#  86.  59.3 71.4 56.  79.3 73.5 71.9 75.3 76.  79.3 75.8 75.4 75.3 82.
#  73.6 71.2 71.1 59.1 71.5 66.  64.9 78.3 73.7 58.9 74.5 76.  61.4 73.
#  72.8 75.8 76.  67.3 68.3 77.7 69.5 74.4 58.2 72.  73.9 72.7 72.4 74.
#  73.9 67.  71.  72.7 73.5 73.6 61.  69.2 73.9 62.6 66.3 67.1 73.  75.7
#  73.4 72.  75.3 64.8 76.  79.3 73.6 56.8 53.2 75.4 45.3 48.1 82.5 54.8
#  53.8 58.6 69.9 78.7 71.7 73.4 74.2 68.4 74.2 62.  46.  74.4 74.7 57.1
#  73.  73.9 65.  76.2 71.  49.3 77.6 73.  59.1 71.  64.3 76.  72.8 69.
#  73.  68.7 81.3 58.2 59.2 56.  79.5 81.4 71.8 65.  75.6 74.9 74.7 56.7
#  73.  81.8 69.6 65.6 81.7 71.9 77.2 61.8 79.5 62.  65.3 77.  71.8 72.7
#  68.3 73.9 67.3 75.7 72.8 71.1 48.5 65.2 55.3 59.  66.9 51.2 67.3 73.4
#  62.3 65.  73.  81.4 65.4 73.2 76.  59.1 69.5 79.7 75.4 66.9 61.1 88.
#  56.2 58.9 79.3 75.7 78.  71.1 79.3 75.  81.1 71.  73.1 55.  76.  67.3
#  76.  67.6 78.5 74.1 75.7 68.2 71.1 49.8 77.3 71.5 64.4 86.  73.3 71.5
#  65.1 67.  71.7 81.4 78.2 49.3 46.4 58.4 71.4 71.  72.2 77.1 67.7 56.9
#  87.  74.1 67.3 78.5 75.8 55.6 66.9 51.6 62.1 74.4 73.9 46.6 67.3 73.8
#  73.6 73.  74.  54.9 67.3 64.9 79.6 73.9 72.7 73.6 59.4 79.4 72.8 73.
#  72.5 61.8 65.2 66.4 81.9 69.5 52.1 76.5 62.8 68.1 75.  79.  73.6 74.9
#  72.4 76.5 75.  71.9 80.  64.3 56.2 52.  74.4 71.  45.3 74.1 46.6 56.7
#  75.8 61.  74.9 49.7 79.2 68.7 71.5 75.  74.5 62.3 80.  62.3 72.4 79.3
#  74.4 75.  74.2 56.5 74.5 67.8 63.3 55.3 71.1 68.  73.3 83.  72.1 49.3
#  59.7 74.5 58.  67.3 65.2 85.  67.3 81.9 82.5 71.2 71.1 65.2 52.1 65.2
#  71.1 74.7 57.2 79.3 83.  79.1 58.1 63.  55.  81.8 82.5 80.  66.8 64.6
#  73.6 74.9 73.6 76.  56.7 61.8 76.  78.9 59.7 66.6 81.3 66.8 73.3 69.2
#  73.  75.4 74.4 53.  72.2 73.5 79.7 67.3 81.2 49.3 71.  81.1 71.1 59.
#  71.2 78.9 81.4 59.7 55.3 75.3 48.5 67.3 56.9 74.5 58.  73.1 75.9 63.7
#  74.7 69.  83.  54.9 61.8 67.9 62.  74.5 67.8 81.9 67.3 69.7 62.3 67.3
#  64.6 71.5 76.9 78.5 67.3 73.8 65.7 61.8 71.9 74.7 72.7 73.5 67.8 78.6
#  73.8 76.  45.3 74.1 78.5 73.  73.3 64.9 53.  55.  48.5 64.4 82.  67.8
#  71.7 82.  48.1 73.6 79.7 74.6 62.2 73.9 47.1 73.  66.  74.7 74.2 71.1
#  80.  75.9 75.4 71.4 85.  54.9 82.6 74.7 72.  75.3 53.6 58.3 55.3 64.7
#  58.4 61.8 73.3 67.3 58.4 71.6 63.8 75.  74.8 65.1 56.5 73.6 64.2 72.8
#  71.5 71.8 71.  85.  66.  74.2 72.2 78.6 70.  75.9 73.2 64.4 61.  71.
#  76.  56.5 72.7 86.  57.3 71.6 71.8 64.5 73.8 66.  67.3 79.7 75.8 59.1
#  73.1 66.8 78.  47.8 73.  79.4 61.8 71.1 72.2 65.2 72.5 71.7 72.8 84.
#  67.  73.3 78.9 78.8 64.  73.9 89.  82.  66.6 69.5 74.9 65.  79.4 78.3
#  71.  71.7 68.  58.4 81.8 72.9 73.9 68.2 46.4 53.6 76.5 74.2 75.  65.1
#  65.9 54.9 81.2 73.4 75.8 69.3 66.3 44.8 56.2 73.  72.7 71.4 64.5 55.3
#  81.1 75.6 83.  67.7 63.3 61.  75.3 75.5 87.  74.4 71.5 51.8 68.  64.9
#  65.5 73.2]

# %% [markdown]
# ### 1.4 Let's try random forests
#
# Finally, we will grow random forests to analyze the data,
# using the `RandomForestRegressor` function from `sklearn.ensemble`. Again, please use your best judgment to choose the initial parameters for tree complexity.
# Finish the following code to look at the "out of bag" (OOB) error as we increase the number of trees in the ensemble.

# %%
from sklearn import ensemble
from tqdm import tqdm

oob_error = []
num_trees = np.arange(50, 1000, 50)

### Your code starts here
# Initialize Random Forest Regressor with OOB Score enabled

# Loop over the range of number of trees

# Plotting the OOB error as the number of trees varies

# %% [markdown]
# Visualize the variable importance of the model, which is the improvement in the loss (Gini index) due to splitting on a given variable, averaged over all of the trees in the forest. (The `.feature_importances_` method of the model may help with this.)

# %%
rf.set_params(n_estimators=500)
model = rf.fit(X_test, y_test)

### Your code starts here
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_157/2581417948.py in <cell line: 0>()
# ----> 1 rf.set_params(n_estimators=500)
#       2 model = rf.fit(X_test, y_test)
#       3
#       4 ### Your code starts here
#
# NameError: name 'rf' is not defined

# %% [markdown]
# Answer the following questions to evaluate the performance of random forests:
#
# 1. Which variables are most important in predicting life expectancy?
#
# 1. What test MSE do you obtain, and how does it compare to the test MSE of the regression tree above?

# %%
### Your code starts here

# %% [markdown]
# [Your answer starts here]

# %% [markdown]
# ## Problem 2: Penguin Culmen Analysis (PCA) (25 points)

# %% [markdown]
# Let's revisit our flightless friends with the new tools we've learned.

# %%
# run the cell to import needed packages

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# just run this cell to read in the data

df = pd.read_csv('https://raw.githubusercontent.com/YData123/sds265-sp26/main/assignments/assn2/penguins.csv')
df = df.drop(columns=['index','year','island'])
df = df.dropna(axis=0)

# encode the labels
species = list(set(df['species']))
df['class'] = LabelEncoder().fit_transform(df['species'])
sex = [int(list(df['sex'])[j]=='male') for j in range(len(df))]
df['sex'] = sex
df = df.drop(columns=['species'])

y = np.array(df['class'])
X = df.copy()
X = X.drop(columns=['class'])

# %%
# just run this cell to standardize

for i in range(5):
    X.iloc[:,i] = (X.iloc[:,i]-np.mean(X.iloc[:,i]))/np.std(X.iloc[:,i])

print(f"X is {X.shape[0]} rows with {X.shape[1]} columns.")
# Out:
# X is 333 rows with 5 columns.
# /tmp/ipykernel_157/619360440.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0      0.991031
# 1     -1.009050
# 2     -1.009050
# 4     -1.009050
# 5      0.991031
#          ...
# 339    0.991031
# 340   -1.009050
# 341    0.991031
# 342    0.991031
# 343   -1.009050
# Name: sex, Length: 333, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.iloc[:,i] = (X.iloc[:,i]-np.mean(X.iloc[:,i]))/np.std(X.iloc[:,i])

# %% [markdown]
# ### 2.1 Run PCA
#
# In the next cell, carry out Principle Component Analysis to reduce the data from 5 dimensions to 2.
#
# Let `pv1` be the first principal vector and let `pv2` be the second principal vector. Let `pcs` be the projection of the data onto the first two principal vectors.

# %%
# your code here
X = X - np.mean(X,0)
pca = PCA()
pca.fit(X)
pcs = pca.fit_transform(X)

pv1 = pca.components_[0]
pv2 = pca.components_[1]
pcs = pca.fit_transform(X)[:,0:2]

# %% [markdown]
# ### 2.2 Principle Component Analysis

# %% [markdown]
# The next cell plots the principal vectors.

# %%
# just run this cell

plt.bar(range(5), pv1)
plt.xticks(range(5), X.columns, rotation='vertical')
plt.show()

plt.bar(range(5), pv2)
plt.xticks(range(5), X.columns, rotation='vertical')
plt.show()

# %% [markdown]
# Are the first two principle vectors orthogonal? Write code to check and also explain conceptually.
#
# Looking at the plot, what are the first two principle components capturing, in terms of the original features we have?

# %%
# your code here
np.abs(np.dot(pv1, pv2) < 1e-15)
# Out:
# np.True_

# %% [markdown]
# Yes the two principle vectors are orthogonal. From the code we are checking that the dot product is 0/very very small which would indicate orthogonality. Conceptually, the fact that the principle vectors are orthogonal tells us that they represent different variations in the data. Looking at one principle vector would show us how the data varies in one way while looking at the other principle vector would tell us how the data varies in another way that is uncorrelated to the first principle vector.
#
# Looking at the plot, the first two principle components are capturing

# %% [markdown]
# ### 2.3 Visualization

# %%
# just run this cell

plt.scatter(principalX.iloc[:, 0], principalX.iloc[:, 1], c = y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_157/1116037897.py in <cell line: 0>()
#       1 # just run this cell
#       2
# ----> 3 plt.scatter(principalX.iloc[:, 0], principalX.iloc[:, 1], c = y)
#       4 plt.show()
#
# NameError: name 'principalX' is not defined

# %% [markdown]
# What is being plotted in this cell above? If you are to add an xlabel and ylabel, what would you call them?
#
# Can you explain why there are pretty much 6 clusters in the plot?
#
# Recall when we plotted using two features of your choice in assignment 2. How are these different and similar?

# %% [markdown]
# [your markdown here]

# %% [markdown]
# ### 2.4 Visualize the decision boundries

# %% [markdown]
# We now want to add the decision boundries to the plot. (Similar to what we did in assignment 2, but this time using the first 2 principle components as x and y.)

# %%
# just run this cell
# the function will again help you plot the decision boundries

def plot_decision_boundaries(X, y, lr, error):
    X2 = np.array(X)
    b = lr.intercept_
    beta = lr.coef_.T
    colors = ['orange', 'pink', 'lightgreen']
    h = 0.015
    x_min, x_max = X2[:, 0].min() - .5, X2[:, 0].max() + .5
    y_min, y_max = X2[:, 1].min() - .5, X2[:, 1].max() + .5
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))
    Z = np.dot(np.c_[xx.ravel(), yy.ravel()], beta) + b
    Z = np.argmax(Z, axis=1)
    Z = Z.reshape(xx.shape)
    fig = plt.figure(figsize=(8,8))
    plt.contourf(xx, yy, Z, levels=[0,.5,1.5,2.5], colors=colors, alpha=0.5)
    for c in range(3):
        mask = (y==c)
        plt.scatter(X2[np.array(mask),0], X2[np.array(mask),1], color=colors[c], label=species[c])

    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    plt.legend(loc='upper left')
    plt.title('error rate: %.2f' % error)
    plt.xlabel(X.columns[0])
    plt.ylabel(X.columns[1])

# %%
principalX

# %%
# your code here

# %% [markdown]
# How do you think the model performed comparing to the models you ran in assignment 2?

# %% [markdown]
# [your markdown here]

# %% [markdown]
# ## Problem 3: PCA Applications -- Faces and Genetics data (25 points)
#
# In this problem, we will apply PCA to two applications. In the first, we will apply PCA to analyze some face image data and try to understand the variation in this data. In the second application, we will apply PCA to some genetics data and recover an interesting connection with geography!

# %%
import numpy as np
from sklearn.decomposition import PCA

# %% [markdown]
# ## Problem 3.1: Face image data
#
# In this problem, we will apply implementation of PCA to analyze face image data from the `olivetti_faces` dataset. The dataset consists of $64 \times 64$ greyscale images of faces taken in a controlled setting, varying lighting, facial expressions (eyes open/closed, smiling/not smiling), and facial details (glass / no glasses). The dataset consists of 40 subjects with 10 images for each. It was collected by AT&T between 1992 and 1994.
#
# We will try to understand the variation in face (images) by performing principal component analysis!

# %% [markdown]
# First, we fetch the dataset and define a utility function for plotting a gallery of images.

# %%
# this cell fetches the data and defines a function to plot the images

import matplotlib.pyplot as plt
from sklearn.datasets import fetch_olivetti_faces

# get data
faces, _ = fetch_olivetti_faces(return_X_y=True)

n_samples, n_features = faces.shape
image_shape = (64, 64)

# define a utility function to plot a gallery of images
def plot_gallery(title, images, n_col=3, n_row=2, cmap=plt.cm.gray):
    fig, axs = plt.subplots(
        nrows=n_row,
        ncols=n_col,
        figsize=(2.0 * n_col, 2.3 * n_row),
        facecolor="white",
        constrained_layout=True,
    )
    fig.set_constrained_layout_pads(w_pad=0.01, h_pad=0.02, hspace=0, wspace=0)
    fig.set_edgecolor("black")
    fig.suptitle(title, size=16)
    for ax, vec in zip(axs.flat, images):
        im = ax.imshow(
            vec.reshape(image_shape),
            cmap=cmap,
            interpolation="nearest",
        )
        ax.axis("off")

    fig.colorbar(im, ax=axs, orientation="horizontal", shrink=0.99, aspect=40, pad=0.01)
    plt.show()

# %%
# plot first 6 images in dataset
plot_gallery("First 6 images", faces[:6, :])

# %% [markdown]
# ### Problem 3.1.1: Fit PCA and visualize the top principal vectors

# %%
# fit PCA to the `faces` data. Use `n_components=None` to compute the maximal number of principal vectors
# your code here

# %%
# extract the principal vectors from the fitted PCA object
... # your code here
plot_gallery("Principal vectors ('eigenfaces')", face_principal_vectors)

# %% [markdown]
# ### Problem 3.1.2: Visualize explained variance of the top $k$ principal vectors
#
# When we compute PCA, we can get the "explained variance" of each principal vector. In this problem, we will visualize the explained variance to better-understand the variation in the data.
#
# Recall that in `sklearn`'s implementation of PCA, the explained variance ratio of the $i$ th principal vector is given by `pca.explained_variance_ratio_[i]`. This is a number between 0 and 1. You can think of this as the percentage of the variation in the data in the direction of the $i$ th principal vector.
#
# Then, we can define the cumulative explained variance of the top $k$ principal vectors as,
# $$\mathrm{cumulative\_explained\_variance\_ratio}(k) = \sum_{i=1}^{k} \mathrm{explained\_variance\_ratio}(i).$$
#
# This quantity represents the proportion of the variation in the data which is explained by the first $k$ principal vectors. In this problem, we will plot $k$ against against $\mathrm{explained\_variance\_ratio}(k)$ and $\mathrm{cumulative\_explained\_variance\_ratio}(k)$. This gives us an idea of how many directions account for most of the variation in the data.
#
# ------
# **Aside**: How is the "explained variance ratio" obtained?
#
# Recall that PCA is computed via the eigenvectors and eigenvalues of the empirical covariance matrix. Let $S$ be the empirical covariance matrix. Then, its eigenvectors $v_i$ are the principal vectors. Denote the eigenvalue of the $i$ th eigenvector by $\lambda_i$. In `sklearn`, the eigenvalues are accessible via `pca.explained_variance_`; $\lambda_i$ is `pca.explained_variance_[i]`. The "explained variance ratio" is a ratio of each eigenvalue to the sum of the eigenvalues. That is, $\mathrm{explained\_variance\_ratio}(i) = \lambda_i / \sum_j \lambda_j$.
#
# The eigenvalue of a particular eigenvector of the covariance matrix will be larger when there is more variation in that direction. The "ratio" part of explained variance simply normalizes these eigenvalues so that they sum to 1, giving the quantity an interpretation as the proportion of the variance explained by a particular direction.

# %%
# plot the explained variance of the top k principal components as a function of k

# extract the explained variance ratio of each principal vector
explained_variance_ratio_per_component = ... # your code here

# compute cumulative explained variance ratio upto k components for each k
cumulative_explained_variance_ratio = ... # your code here (hint: you can use np.cumsum or do the sum yourself)

# plot the explained variance ratio per component and the cumulative explained variance ratio
fig, (ax1, ax2) = plt.subplots(figsize=(10, 5), ncols=2)
ax1.plot(explained_variance_ratio_per_component)
ax1.set_xlabel('component');
ax1.set_ylabel('explained variance per component');


ax2.plot(cumulative_explained_variance_ratio)
ax2.set_xlabel('number of principal vectors');
ax2.set_ylabel('cumulative explained variance');

# %% [markdown]
# Comment on the curve you observe. Roughly how many principal vectors are required to explain 90\% of the variance? What does this tell you about the underlying variation in the data?
#
# [Your markdown here]
#
# **Solution**

# %% [markdown]
# ### Problem 3.1.3: Reconstructing data from principal components
#
# In this question, we will use PCA to re-construct the face images from fewer principal components. The plots above show that most of the variance in the data is explained by the first few principal components. In this question, we will visualize this by reconstructing a face image using the first $k$ principal components, varying $k$. We will then use the face image PCA to (attempt to) reconstruct an image of an octopus.
#
# Recall that the first $k$ principal components, $v_1, \ldots, v_k$ give an orthonormal basis for a $k$-dimensional subspace of the data. The first $k$ principal components of a point $x \in \mathbb{R}^d$ are given by $\left(v_1^\top (x - \bar{x}), \ldots, v_k^\top (x - \bar{x})\right)$. Each principal component represents the amount of $x$ that lies in the direction of the corresponding principal vector. The principal components can then be used to reconstruct $x$ via,
#
# $$\hat{x} = \bar{x} + \sum_{i=1}^k \left(v_i^\top (x - \bar{x})\right) v_i.$$
#
# This is essentially a projection onto the $k$-dimensional subspace spanned by the principal vectors $v_1, \ldots, v_k$ (after centering by the mean).
#
# In the `sklearn` implementation of PCA, the mean vector $\bar{x}$ is accessible via `pca.mean_` and the principal vectors are accessible by `pca.compnents_`.
#
# Implement a function `project_principal_vectors` which computes $\hat{x}$ for a given $x$, reconstructing a point in terms of the principal vectors.

# %%
def project_principal_vectors(x, principal_vecs, mean_x, k):
    """
    project a data point onto the first k principal vectors

    Parameters
    ----------
    x : np.ndarray of shape (d,)
        test data point
    principal_vecs : np.ndarray of shape (min(d, n), d)
        array of eigenvectors where eig_vecs[i] is the ith eigenvector
    mean_x : np.ndarray of shape (d,)
        the mean vector of the data
    k : int
        number of principal vectors to project onto

    Returns
    -------
    np.ndarray of shape (d,)
        the projection of x onto the first k principal vectors
    """

    # center the data point
    centered_x = ... # your code here

    # compute the projection onto the first k principal components
    projection = mean_x + sum([
        ... # your code here
        for i in range(k)])

    return projection

# %%
# extract mean vector and principal components from fitted PCA object
face_mean_x = ... # your code here
face_principal_vectors = ... # your code here


face = faces[0] # consider the first image in the dataset (you can change this to any image in the dataset)
fig, axs = plt.subplots(figsize=(20,6), ncols=9)

# plot the original image
axs[0].imshow(face.reshape(image_shape), cmap='gray')
axs[0].set_title('original')

for rotated_ax, k in zip(axs[1:], [1, 5, 10, 50, 100, 200, 300, 400]):
    # compute the reconstruction using the first k principal components using `project_principal_vectors`
    reconstruction = ... # your code here

    # plot the reconstructed image using the first k principal components
    rotated_ax.imshow(reconstruction.reshape(image_shape), cmap='gray')
    rotated_ax.set_title(f'k={k}')

# %% [markdown]
# What happens if we try to apply our PCA algorithm, which was fitted on images of faces, to an image of something that is not a face? Let's try! Below, we'll attempt to use PCA to reconstruct an image of a cute octopus.

# %%
# source of image: "https://i.pinimg.com/originals/6d/dc/5a/6ddc5a4845441a5d93583a8b2f8f562f.jpg"
# the cute_octopus.png file is a cropped, reshaped, and grayscale version of the image
from PIL import Image
import urllib

url = 'https://raw.githubusercontent.com/YData123/sds265-sp26/main/assignments/assn3/cute_octopus.png'
cute_octopus = np.array(Image.open(urllib.request.urlopen(url)))
plt.imshow(cute_octopus, cmap='gray')
cute_octopus = cute_octopus.flatten() # flatten the image into a vector

# %%
# extract mean vector and principal components from PCA object fitted to face data
... # your code here
... # your code here


fig, axs = plt.subplots(figsize=(20,6), ncols=9)

# plot the original image
axs[0].imshow(cute_octopus.reshape(image_shape), cmap='gray')
axs[0].set_title('original')

for rotated_ax, k in zip(axs[1:], [1, 5, 10, 50, 100, 200, 300, 400]):
    # compute the reconstruction using the first k principal components using `project_principal_vectors`
    reconstruction = ... # your code here

    # plot the reconstructed image using the first k principal components
    rotated_ax.imshow(reconstruction.reshape(image_shape), cmap='gray')
    rotated_ax.set_title(f'k={k}')

# %% [markdown]
# What do you observe about the reconstruction of the face image? How well do the reconstructed images match the original image at each $k$. What about the reconstruction of the octopus? Why do you think this is what we observe?
#
# [Your markdown here]
#
# **Solution**

# %% [markdown]
# ## Problem 3.2: Analyzing genetics data
#
# In this sub-problem, we will PCA to analyzing genetics data. The data we will use comes from the [1000 Genomes Project](https://www.internationalgenome.org/).
#
# A single-nucleotide polymorphism is a substitution of a single nucleotide at a specific location in the genome which is present in a sufficiently large segment of the population. An ancestry-informative SNP (AISNP) is a SNP which has significant variation across global populations. There exists a line of work identifying AISNPs. In this problem, we will use 55 AISNPs identified by [Kidd et al.](https://pubmed.ncbi.nlm.nih.gov/24508742/). We have pre-processed this data for you.
#
# In this problem, you will use PCA to visualize and analyze this data.

# %%
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder
from sklearn.decomposition import PCA

# %%
# read in the SNP data
snp_data = pd.read_csv('https://raw.githubusercontent.com/YData123/sds265-fa23/main/assignments/assn3/1000genomes_snp_data.csv')
snp_cols = [col for col in snp_data.columns if col.startswith('rs')]
sample_attr_cols = ['pop', 'super_pop', 'gender']
snp_data.head()

# %%
# one-hot encode the SNP data using sklearn's OneHotEncoder for use with PCA
import sklearn
try:
    ohe = OneHotEncoder(sparse_output=False)
except TypeError:
    ohe = OneHotEncoder(sparse=False)
X = ohe.fit_transform(snp_data[snp_cols].values)

# %%
# fit PCA on the snp data in X; set the number of components to 2
... # your code here

# compute first two principal components of each sample in X
...  # your code here

# add the principal components to the snp_data dataframe
... # your code here

# %%
# plot the principal components in a scatter plot with super population color-coded

fig, ax = plt.subplots(figsize=(6, 6))
sns.scatterplot(data=snp_data, x='PC1', y='PC2', hue='super_pop', alpha=0.5, ax=ax);

# %% [markdown]
# Take a look at this plot and think about any trends you see. Do you see any connection with geography?
#
# Below, we will rotate this plot so that the center of the EUR and AFR samples on the PC plot lie vertically on top of each other.

# %%
# compute mean PC1 and PC2 for each super population
mean_by_superpop = snp_data.groupby('super_pop')[['PC1', 'PC2']].mean()
afr_pc_mean = mean_by_superpop.loc['AFR'].to_numpy()
eur_pc_mean = mean_by_superpop.loc['EUR'].to_numpy()

# compute angle between center of AFR and EUR clusters
angle = np.arctan2(eur_pc_mean[1] - afr_pc_mean[1], eur_pc_mean[0] - afr_pc_mean[0])
print(f'angle between AFR and EUR principal components: {angle:.2f} radians')

# %%
def create_rotation_mat(angle):
    '''creates 2D rotation matrix for given angle'''
    c, s = np.cos(angle), np.sin(angle)
    rotation_matrix = np.array(((c, -s), (s, c)))
    return rotation_matrix

# rotate the principal components by the angle between the AFR and EUR clusters
rotation_mat = create_rotation_mat(angle - np.pi/2)
rotated_pcs = snp_data[['PC1', 'PC2']].to_numpy() @ rotation_mat

# create lines denoting the principal components in the rotated axes
pc1_line = [(pc1, 0) for pc1 in ax.get_xlim()]
pc2_line = [(0, pc2) for pc2 in ax.get_ylim()]
pc1_line_rotated = pc1_line @ rotation_mat
pc2_line_rotated = pc2_line @ rotation_mat

# %%
# plot rotated principal components
fig, ax = plt.subplots(figsize=(6, 6))
sns.scatterplot(x=rotated_pcs[:, 0], y=rotated_pcs[:, 1], hue=snp_data['super_pop'], alpha=0.5);
ax.plot(pc1_line_rotated[:,0], pc1_line_rotated[:,1], color='black', linestyle='--', label='PC1');
ax.plot(pc2_line_rotated[:,0], pc2_line_rotated[:,1], color='black', linestyle='--', label='PC2');

# %% [markdown]
# For reference, below is a cartogram of the global population from wikipedia. It shows a map of the world with land area scaled according to population.
#
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/9/90/Global_population_cartogram.png" width=1000px/>

# %% [markdown]
# Comment on any patterns you observe. Are "super populations" which are geographically closer also closer in terms of their first two principal components? Can you suggest any explanations for the patterns you observe?

# %% [markdown]
# [Your markdown here]
#
# **Solution:**

# %% [markdown]
# ## Problem 4: Bayes’ Theorem (10 points)
#
# Bayes’ theorem provides a systematic way to update beliefs based on new evidence. It is a powerful tool in probability and statistics, and it is also useful for understanding many real-world phenomena.

# %% [markdown]
# ### Problem 4.1: Counterintuitive Example in Disease Prediction
# Machine learning models are increasingly used in clinical situations. A common and counterintuitive point, often missed even by experienced doctors, is that for rare conditions, highly accurate tests can still produce many false positive results. Since false positives can trigger additional tests, costs, and anxiety, this fact has important implications for clinical practice. Screening and early detection policies often aim to balance benefits and harms, and may focus on high-risk groups. For example, X-ray examinations for breast cancer are often only recommended for women who are older than 40. Such an X-ray examination in young women can be more harmful.
#
# The following calculation could help you understand the phenomenon:
#
# For a woman in her 40s, the probability of having a breast cancer is 7 in 1,000 $P(P \mid D) = 0.7\%$. The X-ray test has a sensitivity of 0.9 and a false positive rate of 0.07, which means that 9 out of 10 women who truly have breast cancer will test positive, while 7 out of 100 women who do not have breast cancer will still test positive.
#
# If a woman in her 40s tests positive, what is the probability that the woman really has the breast cancer?

# %% [markdown]
# [Your answer should be here]

# %% [markdown]
# **Suggested further reading:** Steven Strogatz, *“Chances Are”* (https://archive.nytimes.com/opinionator.blogs.nytimes.com/2010/04/25/chances-are/).

# %% [markdown]
# ### Problem 4.2 Dirichlet Distribution in Cancer Subtype
#
# Accurately identifying cancer subtypes is crucial because subtype information can directly affect therapy choices and prognosis. However, subtype classification can be difficult in practice: different diagnostic methods have different advantages, and the most accurate methods often require a biopsy, which can harm patients. By contrast, noninvasive methods are usually less accurate. Therefore, it is important to choose the best method for the specific clinical situation.
#
# Consider four common breast cancer subtypes: Luminal A, Luminal B, HER2-enriched, and Triple-negative.
# We assume no prior preference over the 4 subtypes:
#
# Let $\boldsymbol{\theta} = (\theta_1, \theta_2, \theta_3, \theta_4)$ denote the cancer subtype probabilities.
#
# We use a uniform Dirichlet prior:
#
# $$
# \boldsymbol{\theta} \sim \mathrm{Dir}(1,1,1,1).
# $$
#
# In a specific region, we observe **20** independent cases with the following counts: Luminal A (10 cases), Luminal B (4 cases), HER2-enriched (4 cases), and Triple-negative (2 cases).
#
# Then, **1)** compute the posterior distribution of $\boldsymbol{\theta}$ and **2)** There is a diagnostic test: for patients with the triple-negative subtype, the probability of testing positive is 0.9; for patients with other subtypes, the probability of testing positive is 0.1. The 21st patient tests positive, compute the posterior probability that the 21st patient belongs to the triple-negative subtype.

# %% [markdown]
# [Your answer should be here]
